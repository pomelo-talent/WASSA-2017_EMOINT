# %% [markdown]
# # 1. Data Preprocessing

# %% [markdown]
# # (1) Reading the Training, the Development and the Testing Datasets

# %%
import pandas as pd
from os import listdir

import matplotlib.pyplot as plt
import numpy as np

# %%
directory1 = 'data/train'
paths1 = listdir(directory1)
paths1.sort()
paths1
# Out:
# ['anger-ratings-0to1.train.txt',
#  'fear-ratings-0to1.train.txt',
#  'joy-ratings-0to1.train.txt',
#  'sadness-ratings-0to1.train.txt']

# %%
train_anger = pd.read_csv('%s/%s' %(directory1,paths1[0]), delimiter='\t',header=None)
train_anger.head()
# Out:
#        0                                                  1      2      3
# 0  10000  How the fu*k! Who the heck! moved my fridge!.....  anger  0.938
# 1  10001  So my Indian Uber driver just called someone t...  anger  0.896
# 2  10002  @DPD_UK I asked for my parcel to be delivered ...  anger  0.896
# 3  10003  so ef whichever butt wipe pulled the fire alar...  anger  0.896
# 4  10004  Don't join @BTCare they put the phone down on ...  anger  0.896

# %%
train_anger.columns = ['SentID', 'Tweet', 'Emotion', 'Rating']
train_anger[:10]
# Out:
#    SentID                                              Tweet Emotion  Rating
# 0   10000  How the fu*k! Who the heck! moved my fridge!.....   anger   0.938
# 1   10001  So my Indian Uber driver just called someone t...   anger   0.896
# 2   10002  @DPD_UK I asked for my parcel to be delivered ...   anger   0.896
# 3   10003  so ef whichever butt wipe pulled the fire alar...   anger   0.896
# 4   10004  Don't join @BTCare they put the phone down on ...   anger   0.896
# 5   10005                                My blood is boiling   anger   0.875
# 6   10006  When you've still got a whole season of Wentwo...   anger   0.875
# 7   10007  @bt_uk why does tracking show my equipment del...   anger   0.875
# 8   10008  @TeamShanny legit why i am so furious with him...   anger   0.875
# 9   10009  How is it suppose to work if you do that? Wtf ...   anger   0.875

# %%
train_fear = pd.read_csv('%s/%s' %(directory1,paths1[1]), delimiter='\t',header=None)
train_fear.columns = train_anger.columns

train_joy = pd.read_csv('%s/%s' %(directory1,paths1[2]), delimiter='\t',header=None) 
train_joy.columns = train_anger.columns

train_sadness = pd.read_csv('%s/%s' %(directory1,paths1[3]), delimiter='\t',header=None) 
train_sadness.columns = train_anger.columns

# %%
# check if there are any duplicates(subset = all of the columns)

assert train_fear.duplicated().sum() == 0
assert train_anger.duplicated().sum() == 0
assert train_joy.duplicated().sum() == 0
assert train_sadness.duplicated().sum() == 0

# %%
# checking missing data & len(train),len(test)
print(train_anger.info(), train_fear.info(), train_joy.info(), train_sadness.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 857 entries, 0 to 856
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   SentID   857 non-null    int64
#  1   Tweet    857 non-null    object
#  2   Emotion  857 non-null    object
#  3   Rating   857 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 26.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1147 entries, 0 to 1146
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   SentID   1147 non-null   int64
#  1   Tweet    1147 non-null   object
#  2   Emotion  1147 non-null   object
#  3   Rating   1147 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 36.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   SentID   823 non-null    int64
#  1   Tweet    823 non-null    object
#  2   Emotion  823 non-null    object
#  3   Rating   823 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 25.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 786 entries, 0 to 785
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   SentID   786 non-null    int64
#  1   Tweet    786 non-null    object
#  2   Emotion  786 non-null    object
#  3   Rating   786 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 24.7+ KB
# None None None None

# %%
print(train_anger.describe(), "\n", train_fear.describe(), "\n", train_joy.describe(), "\n", train_sadness.describe() )
# Out:
#              SentID      Rating
# count    857.000000  857.000000
# mean   10428.000000    0.496475
# std      247.538886    0.169169
# min    10000.000000    0.067000
# 25%    10214.000000    0.375000
# 50%    10428.000000    0.479000
# 75%    10642.000000    0.604000
# max    10856.000000    0.938000
#               SentID       Rating
# count   1147.000000  1147.000000
# mean   20573.000000     0.495579
# std      331.254686     0.194792
# min    20000.000000     0.062000
# 25%    20286.500000     0.354000
# 50%    20573.000000     0.479000
# 75%    20859.500000     0.625000
# max    21146.000000     0.979000
#              SentID      Rating
# count    823.00000  823.000000
# mean   30411.00000    0.492618
# std      237.72393    0.204334
# min    30000.00000    0.019000
# 25%    30205.50000    0.340000
# 50%    30411.00000    0.480000
# 75%    30616.50000    0.646000
# max    30822.00000    0.980000
#               SentID      Rating
# count    786.000000  786.000000
# mean   40392.500000    0.495957
# std      227.042947    0.190841
# min    40000.000000    0.083000
# 25%    40196.250000    0.351750
# 50%    40392.500000    0.479000
# 75%    40588.750000    0.646000
# max    40785.000000    0.958000

# %%
# check the counts of observations in each categorical bin using bars (to see if we need data balance.)
d_train = [train_anger.shape[0], train_fear.shape[0], train_joy.shape[0], train_sadness.shape[0]]
labels= ["anger", "fear", "joy", "sadness"]
plt.bar(labels, d_train,tick_label=labels)
plt.show()

# %%
directory2 = 'data/dev'
paths2 = listdir(directory2)
paths2.sort()
paths2

dev_anger = pd.read_csv('%s/%s' %(directory2,paths2[0]), delimiter='\t',header=None)
dev_anger.columns = train_anger.columns
dev_anger[:10]
# Out:
#    SentID                                              Tweet Emotion  Rating
# 0   10857  @ZubairSabirPTI  pls dont insult the word 'Molna'   anger   0.479
# 1   10858  @ArcticFantasy I would have almost took offens...   anger   0.458
# 2   10859  @IllinoisLoyalty that Rutgers game was an abom...   anger   0.562
# 3   10860  @CozanGaming that's what lisa asked before she...   anger   0.500
# 4   10861  Sometimes I get mad over something so minuscul...   anger   0.708
# 5   10862  Sometimes I get mad over something so minuscul...   anger   0.646
# 6   10863  I think @Sam_Canaday &amp; @KYLEJDOWSON must a...   anger   0.250
# 7   10864  My eyes have been dilated. I hate the world ri...   anger   0.812
# 8   10865  @huwellwell One chosen by the CLP members! MP ...   anger   0.682
# 9   10866  @huwellwell One chosen by the CLP members! MP ...   anger   0.438

# %%
dev_fear = pd.read_csv('%s/%s' %(directory2,paths2[1]), delimiter='\t',header=None)
dev_fear.columns = train_anger.columns

dev_joy = pd.read_csv('%s/%s' %(directory2,paths2[2]), delimiter='\t',header=None) 
dev_joy.columns = train_anger.columns

dev_sadness = pd.read_csv('%s/%s' %(directory2,paths2[3]), delimiter='\t',header=None) 
dev_sadness.columns = train_anger.columns

# %%
# check if there are any duplicates(subset = all of the columns)

assert dev_fear.duplicated().sum() == 0
assert dev_anger.duplicated().sum() == 0
assert dev_joy.duplicated().sum() == 0
assert dev_sadness.duplicated().sum() == 0

# %%
# checking missing data & len(train),len(test)
print(dev_fear.info(), dev_fear.info(), dev_joy.info(), dev_sadness.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   SentID   110 non-null    int64
#  1   Tweet    110 non-null    object
#  2   Emotion  110 non-null    object
#  3   Rating   110 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   SentID   110 non-null    int64
#  1   Tweet    110 non-null    object
#  2   Emotion  110 non-null    object
#  3   Rating   110 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   SentID   79 non-null     int64
#  1   Tweet    79 non-null     object
#  2   Emotion  79 non-null     object
#  3   Rating   79 non-null     float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 2.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   SentID   74 non-null     int64
#  1   Tweet    74 non-null     object
#  2   Emotion  74 non-null     object
#  3   Rating   74 non-null     float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 2.4+ KB
# None None None None

# %%
print(dev_anger.describe(), "\n", dev_fear.describe(), "\n", dev_joy.describe(), "\n", dev_sadness.describe() )
# Out:
#              SentID     Rating
# count     84.000000  84.000000
# mean   10898.500000   0.489607
# std       24.392622   0.156768
# min    10857.000000   0.125000
# 25%    10877.750000   0.410250
# 50%    10898.500000   0.500000
# 75%    10919.250000   0.590500
# max    10940.000000   0.860000
#               SentID      Rating
# count    110.000000  110.000000
# mean   21201.500000    0.489309
# std       31.898276    0.185675
# min    21147.000000    0.060000
# 25%    21174.250000    0.354000
# 50%    21201.500000    0.466500
# 75%    21228.750000    0.632500
# max    21256.000000    0.896000
#               SentID     Rating
# count     79.000000  79.000000
# mean   30862.000000   0.483392
# std       22.949219   0.219682
# min    30823.000000   0.038000
# 25%    30842.500000   0.312000
# 50%    30862.000000   0.479000
# 75%    30881.500000   0.653000
# max    30901.000000   0.936000
#               SentID     Rating
# count     74.000000  74.000000
# mean   40822.500000   0.475743
# std       21.505813   0.178436
# min    40786.000000   0.125000
# 25%    40804.250000   0.340750
# 50%    40822.500000   0.458000
# 75%    40840.750000   0.625000
# max    40859.000000   0.875000

# %%
# check the counts of observations in each categorical bin using bars (to see if we need data balance.)
d_dev = [dev_anger.shape[0], dev_fear.shape[0], dev_joy.shape[0], dev_sadness.shape[0]]
labels= ["anger", "fear", "joy", "sadness"]
plt.bar(labels, d_dev,tick_label=labels)
plt.show()

# %%
directory3 = 'data/test'
paths3 = listdir(directory3)
paths3.sort()
paths3

test_anger = pd.read_csv('%s/%s' %(directory3,paths3[0]), delimiter='\t',header=None)
test_anger.columns = train_anger.columns

test_anger[:10]
# Out:
#    SentID                                              Tweet Emotion  Rating
# 0   10941  At the point today where if someone says somet...   anger   0.319
# 1   10942  @CorningFootball  IT'S GAME DAY!!!!      T MIN...   anger   0.144
# 2   10943  This game has pissed me off more than any othe...   anger   0.898
# 3   10944  @spamvicious I've just found out it's Candice ...   anger   0.271
# 4   10945  @moocowward @mrsajhargreaves @Melly77 @GaryBar...   anger   0.646
# 5   10946  @moocowward @mrsajhargreaves @Melly77 @GaryBar...   anger   0.583
# 6   10947  wanna go home and focus up on this game . Don'...   anger   0.375
# 7   10948  @virginmedia I've been disconnected whilst on ...   anger   0.625
# 8   10949  @virginmedia I've been disconnected whilst on ...   anger   0.396
# 9   10950  I wanna see you smile I don't wanna see you ma...   anger   0.250

# %%
test_fear = pd.read_csv('%s/%s' %(directory3,paths3[1]), delimiter='\t',header=None)
test_fear.columns = train_anger.columns

test_joy = pd.read_csv('%s/%s' %(directory3,paths3[2]), delimiter='\t',header=None) 
test_joy.columns = train_anger.columns

test_sadness = pd.read_csv('%s/%s' %(directory3,paths3[3]), delimiter='\t',header=None) 
test_sadness.columns = train_anger.columns

# %%
# check if there are any duplicates(subset = all of the columns)

assert test_fear.duplicated().sum() == 0
assert test_anger.duplicated().sum() == 0
assert test_joy.duplicated().sum() == 0
assert test_sadness.duplicated().sum() == 0

# %%
# checking missing data & len(train),len(test)
print(test_anger.info(), test_fear.info(), test_joy.info(), test_sadness.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 760 entries, 0 to 759
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   SentID   760 non-null    int64
#  1   Tweet    760 non-null    object
#  2   Emotion  760 non-null    object
#  3   Rating   760 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 23.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   SentID   995 non-null    int64
#  1   Tweet    995 non-null    object
#  2   Emotion  995 non-null    object
#  3   Rating   995 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 31.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   SentID   714 non-null    int64
#  1   Tweet    714 non-null    object
#  2   Emotion  714 non-null    object
#  3   Rating   714 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 22.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 673 entries, 0 to 672
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   SentID   673 non-null    int64
#  1   Tweet    673 non-null    object
#  2   Emotion  673 non-null    object
#  3   Rating   673 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 21.2+ KB
# None None None None

# %%
print(test_anger.describe(), "\n", test_fear.describe(), "\n", test_joy.describe(), "\n", test_sadness.describe() )
# Out:
#              SentID      Rating
# count    760.000000  760.000000
# mean   11320.500000    0.502149
# std      219.537392    0.171886
# min    10941.000000    0.032000
# 25%    11130.750000    0.375000
# 50%    11320.500000    0.496000
# 75%    11510.250000    0.625000
# max    11700.000000    0.976000
#              SentID     Rating
# count    995.00000  995.00000
# mean   21754.00000    0.50247
# std      287.37606    0.20094
# min    21257.00000    0.06200
# 25%    21505.50000    0.35400
# 50%    21754.00000    0.50000
# 75%    22002.50000    0.64600
# max    22251.00000    1.00000
#               SentID      Rating
# count    714.000000  714.000000
# mean   31258.500000    0.508958
# std      206.258333    0.217295
# min    30902.000000    0.000000
# 25%    31080.250000    0.340000
# 50%    31258.500000    0.500000
# 75%    31436.750000    0.673000
# max    31615.000000    0.980000
#              SentID      Rating
# count    673.00000  673.000000
# mean   41196.00000    0.511272
# std      194.42265    0.202737
# min    40860.00000    0.083000
# 25%    41028.00000    0.354000
# 50%    41196.00000    0.500000
# 75%    41364.00000    0.667000
# max    41532.00000    1.000000

# %%
# check the counts of observations in each categorical bin using bars (to see if we need data balance.)
d_test = [test_anger.shape[0], test_fear.shape[0], test_joy.shape[0], test_sadness.shape[0]]
labels= ["anger", "fear", "joy", "sadness"]
plt.bar(labels, d_test,tick_label=labels)
plt.show()

# %%
# show the number of instances in the Tweet Emotion Intensity dataset.

Table_1 = pd.DataFrame(np.array([(d_train), (d_dev), (d_test)])).T
Table_1.columns = ['Train', 'Dev.', 'Test']
Table_1.index = ['anger', 'fear', 'joy', 'sadness']
Table_1['All'] = Table_1.apply(lambda x: x.sum(), axis=1)
Table_1.loc['All'] = Table_1.apply(lambda x: x.sum())

Table_1
# Out:
#          Train  Dev.  Test   All
# anger      857    84   760  1701
# fear      1147   110   995  2252
# joy        823    79   714  1616
# sadness    786    74   673  1533
# All       3613   347  3142  7102

# %% [markdown]
# # (2) Define Text Data Cleaning Process

# %%
import string
import re

from nltk.corpus import stopwords

import wordsegment as ws # $ pip install wordsegment    
ws.load()     

import emoji  # $ pip install emoji

# As the glove model contains many words made with grammatical role, tense ,or derivational morphology,
# we do not need WordNetLemmatizer or SnowballStemmer here.

# %%
def normalize_text(text):
     # replace emoji to word
    text = emoji.demojize(text)
    
    # remove characters outside the ascii code 128
    text = ''.join([w if ord(w)<128 else ' ' for w in text])
    
    # replace '--' with a space
    text = text.replace('--',' ')
    
    # remove any newline characters
    text = text.replace('\n',' ')
    
    # tweets mentions user using '@' followed by username. Replace all those with <user> to be usable for Glove
    text = re.sub('@[^ ]+','<user>',text)
    
    # Replace all URLs with <url> to be usable for Glove
    text = re.sub(r'\d+','<number>',text)
   
    # Replace all numbers with <number> to be usable for Glove
    text = re.sub(r'http\S+','<url>',text)
    
    # turn some abbreviations into a whold word
    text = re.sub(r"\'s", "", text)
    text = re.sub(r"\'m", " am", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"can\'t", "can not", text)
    text = re.sub(r"won\'t", "will not", text)
    text = re.sub(r"n\'t", " not", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"fu\*k", " fuck", text)
    text = re.sub(r"f\*c+", "fuck", text)
    text = text.replace("wtf", "what the fuck")
    
    # prepare spaces between punctuation and words
    text1 = text.split('...')
    for i in range(len(text1)):
        text1[i] = text1[i].replace('/',' / ').replace('\\',' \ ').replace(',',' , ').replace('.',' . ').replace('?',' ? ').replace('!',' ! ').replace("'"," ' ").replace(':',' : ').replace(';',' ; ').replace('-',' - ').replace('(',' ( ').replace(')',' ) ').replace('[',' [ ').replace(']',' ] ').replace('&',' & ').replace('*',' * ').replace('{',' { ').replace('}',' } ').replace('-',' - ').replace('`',' ` ').replace('"',' " ').replace('>','> ').replace('<',' <')
    text1 = ' '.join(text1)
    
    # split into tokens by white space
    tokens = text1.split()
    
    return tokens

def clean_text(text):
   
    tokens = normalize_text(text)
    
    new_tokens1 = []
    for w in tokens:
        if w == "<user>":
            w = w
        elif w == "<url>":
            w = w
        elif w == "<number>":
            w = w
        else:
            # prepare regex for char filtering: !"#$%&'()*+, -./:;<=>?@[\]^_`{|}~
            re_punc = re.compile('[%s]' %re.escape(string.punctuation))
            # remove punctuation from each word
            w = re_punc.sub('', w)
    
            # remove remaining tokens that are not alphabetic
            if w.isalpha():
                w = w
        new_tokens1.append(w) 
        
    # filter out stop words
    stop_words = set(stopwords.words('english'))
    tokens = [w for w in new_tokens1 if not w in stop_words]
    
    new_tokens2 = []
    for w in tokens:
        if w == "<user>":
            w = w
        elif w == "<url>":
            w = w
        elif w == "<number>":
            w = w
        else:
            # word segment will convert the hashtag based joined words, for example, it will segment #iamthebest to ['i','am','the','best']
            w = ' '.join(ws.segment(w)) 
        new_tokens2.append(w)
        
    
    # make lower case
    tokens = [word.lower() for word in new_tokens2]
    
    
    clean_text = ' '.join(tokens)
    tokens = clean_text.split()
    
   # filter out short tokens

    tokens = [word for word in tokens if len(word) > 1]
    
    return ' '.join(tokens)

# %% [markdown]
# tokens = normalize_text("@aa   bb #nothappy ab,")
# print(tokens)
# new_tokens = list()
# for w in tokens:
#
#     if w == "<user>":
#         w = w
#     elif w == "<url>":
#         w = w
#     elif w == "<number>":
#         w = w
#     else:
#         # prepare regex for char filtering: !"#$%&'()*+, -./:;<=>?@[\]^_`{|}~
#         re_punc = re.compile('[%s]' %re.escape(string.punctuation))
#         # remove punctuation from each word
#         w = re_punc.sub('', w)
#         # remove remaining tokens that are not alphabetic
#         if w.isalpha():
#             w = w
#     new_tokens.append(w)
#
# print(new_tokens)

# %% [markdown]
# tokens = normalize_text("@aa   bb #nothappy ab,")
# print(tokens)
# new_tokens = list()
# for w in tokens:
#
#     if w == "<user>":
#         w = w
#     elif w == "<url>":
#         w = w
#     elif w == "<number>":
#         w = w
#     else:
#         # prepare regex for char filtering: !"#$%&'()*+, -./:;<=>?@[\]^_`{|}~
#         re_punc = re.compile('[%s]' %re.escape(string.punctuation))
#         # remove punctuation from each word
#         w = re_punc.sub('', w)
#         # remove remaining tokens that are not alphabetic
#         if w.isalpha():
#             w = w
#     new_tokens.append(w)
#
# print(new_tokens)
#
# new_tokens1 = ["  "]
# tokens = [word for word in new_tokens1 if len(word) > 1]
# tokens = [re.sub(r'\s+','',word) for word in tokens]
# print(tokens)
# len(tokens[0])

# %% [markdown]
# tokens = ["<user>", "<url>","number>", "a", "b", "newera"]
# new_tokens2 = []
# for w in tokens:
#     if w == "<user>":
#         w = w
#         new_tokens2.append(w)
#     elif w == "<url>":
#         w = w
#         new_tokens2.append(w)
#
#     elif w == "<number>":
#         w = w
#         new_tokens2.append(w)
#
#     else:
#         # word segment will convert the hashtag based joined words, for example, it will segment #iamthebest to ['i','am','the','best']
#         w1 = ' '.join(ws.segment(w))
#     new_tokens2 += w1.split()
#
# new_tokens2

# %% [markdown]
# b = ["a", "b"]
# a = ws.segment("newworld")
# b += (" ".join(a)).split()
# b

# %% [markdown]
# c = ['a', 'b', 'new world']
# c = ' '.join(c)
# c.split()

# %% [markdown]
# # 2. Text Data Preparation（Feature Extraction)

# %% [markdown]
# # (1) Load Twitter Pretrained Vectors (Glove)

# %%
import numpy as np

# %%
def loadGloveModel(gloveFile):
    print("Loading Glove Model")
    f = open(gloveFile,'r', encoding = 'UTF-8')
    model = {}
    num = 1
    for line in f:
        try:
            splitLine = line.split()
            word = splitLine[0]
            coefs = np.asarray(splitLine[1:], dtype = 'float32')
            model[word] = coefs
            num += 1
        except Exception as e:
            print("Failed at line " + str(num))
    print("Done. Found %s word vectors." %len(model)," words loaded!")
    return model

# %%
# To download the pretrained glove model (2B tweets, 27B tokens) - [https://nlp.stanford.edu/projects/glove/   glove.twitter.27B.zip]
# choose glove.twitter.27B.100d.txt from glove.twitter.27B.zip. [100-dimension vectors]

word_vector_path = "files/wv_models/"
wv_model_path = word_vector_path + "glove.twitter.27B.100d.txt"

wv_model_g = loadGloveModel(wv_model_path)
# Out:
# Loading Glove Model
# Done. Found 1193514 word vectors.  words loaded!

# %% [markdown]
# # (3) Extract Feature with Glove

# %% [markdown]
# # 1) Clean Text Data

# %%
train_anger['Tweet'] = train_anger['Tweet'].apply(clean_text)
train_fear['Tweet'] = train_fear['Tweet'].apply(clean_text)
train_joy['Tweet'] = train_joy['Tweet'].apply(clean_text)
train_sadness['Tweet'] = train_sadness['Tweet'].apply(clean_text)

dev_anger['Tweet'] = dev_anger['Tweet'].apply(clean_text)
dev_fear['Tweet'] = dev_fear['Tweet'].apply(clean_text)
dev_joy['Tweet'] = dev_joy['Tweet'].apply(clean_text)
dev_sadness['Tweet'] = dev_sadness['Tweet'].apply(clean_text)

test_anger['Tweet'] = test_anger['Tweet'].apply(clean_text)
test_fear['Tweet'] = test_fear['Tweet'].apply(clean_text)
test_joy['Tweet'] = test_joy['Tweet'].apply(clean_text)
test_sadness['Tweet'] = test_sadness['Tweet'].apply(clean_text)

# %%
# do a sanity check
train_anger[0:55]
# Out:
#     SentID                                              Tweet Emotion  Rating
# 0    10000  how fuck who heck moved fridge knock landlord ...   anger   0.938
# 1    10001  so indian uber driver called someone word if m...   anger   0.896
# 2    10002  <user> asked parcel delivered pick store addre...   anger   0.896
# 3    10003  ef whichever butt wipe pulled fire alarm davis...   anger   0.896
# 4    10004  do join <user> put phone talk rude taking mone...   anger   0.896
# 5    10005                                   my blood boiling   anger   0.875
# 6    10006  when still got whole season wentworth watch st...   anger   0.875
# 7    10007  <user> tracking show equipment delivered why s...   anger   0.875
# 8    10008         <user> legit furious people fucking idiots   anger   0.875
# 9    10009           how suppose work wtf dude thanks pissing   anger   0.875
# 10   10010        im mad power rangers im incensed im furious   anger   0.667
# 11   10011  wont use using <user> <user> these guys cant g...   anger   0.854
# 12   10012  bitches aggravate like inspires biggest cunt k...   anger   0.854
# 13   10013  why <user> come glasgow night working fucking ...   anger   0.938
# 14   10014            fuking fuming face with steam from nose   anger   0.854
# 15   10015  zero help <user> customer service just pushing...   anger   0.854
# 16   10016  <user> mention gra guy stops let <number> ppl ...   anger   0.854
# 17   10017  hate lawn mower if soul would condemn fiery pi...   anger   0.833
# 18   10018  people offended kendall ends photo shoot like ...   anger   0.833
# 19   10019  block everyone everywhere posting storm think ...   anger   0.812
# 20   10020  making buddy cry bitch wait revenge hugging fa...   anger   0.812
# 21   10021  be you tell true blooded hoop junkie switch fu...   anger   0.891
# 22   10022  got no response rate customer amazon disappoin...   anger   0.812
# 23   10023  tasers immobilize taser someone fuck need shoo...   anger   0.812
# 24   10024  <user> <user> <user> the way blood boiling lit...   anger   0.792
# 25   10025              actually fuming nothing wear saturday   anger   0.792
# 26   10026  <user> straight people even arse straight guys...   anger   0.792
# 27   10027  bloody parking ticket unam used face money wit...   anger   0.792
# 28   10028  you ever find people around really irritate so...   anger   0.792
# 29   10029  get angry people know stop sign francis foster...   anger   0.792
# 30   10030            this fuck boiling inside gonna good let   anger   0.792
# 31   10031  <user> <user> wow my bill <number> <number> ha...   anger   0.792
# 32   10032  blame whole season natalie the season would di...   anger   0.792
# 33   10033  since update <user> loses power nearly <number...   anger   0.792
# 34   10034                           <user> fly fit rage fair   anger   0.792
# 35   10035  unbelievable takes <number> minutes get <user>...   anger   0.792
# 36   10036  <user> <user> we blaming <number> fucking idio...   anger   0.792
# 37   10037                            <user> people infuriate   anger   0.792
# 38   10038  <user> mine party decide party slowly transfor...   anger   0.792
# 39   10039  so angry <user> order <number> months ago plac...   anger   0.771
# 40   10040         still log fucking snap chat snap chat snap   anger   0.900
# 41   10041  <user> sam yes not helpful we need sorting asa...   anger   0.771
# 42   10042  someone let snakes in my house bet it <user> k...   anger   0.771
# 43   10043  ef whichever butt wipe pulled fire alarm davis...   anger   0.771
# 44   10044  why <user> come glasgow night working fucking ...   anger   0.733
# 45   10045                                       feel furious   anger   0.771
# 46   10046  some mexican ladies irritate fuck outta have l...   anger   0.771
# 47   10047              still log fucking snap chat snap chat   anger   0.771
# 48   10048  blame whole season natalie the season would di...   anger   0.771
# 49   10049                            people irritate mf soul   anger   0.771
# 50   10050   im angry face with tears of joy upside down face   anger   0.750
# 51   10051                             people fuckin irritate   anger   0.750
# 52   10052  <user> cruel cruel man there will be blood rev...   anger   0.840
# 53   10053  that way ur angry literally feel ur blood boiling   anger   0.750
# 54   10054          <user> amount greedy mooching makes snarl   anger   0.750

# %%
# show the distribution of text length (from below: there is no need to truncate any of texts)
def show_text_len(train):
    train["text_len"] = train['Tweet'].map(lambda x: len(x.split()))
    return train["text_len"]

# %%
show_text_len(train_fear).describe()
# Out:
# count    1147.000000
# mean       11.174368
# std         4.581159
# min         2.000000
# 25%         8.000000
# 50%        11.000000
# 75%        15.000000
# max        28.000000
# Name: text_len, dtype: float64

# %%
show_text_len(train_joy).describe()
# Out:
# count    823.000000
# mean      10.946537
# std        4.613485
# min        1.000000
# 25%        8.000000
# 50%       11.000000
# 75%       14.000000
# max       33.000000
# Name: text_len, dtype: float64

# %%
show_text_len(train_sadness).describe()
# Out:
# count    786.000000
# mean      11.170483
# std        5.692005
# min        1.000000
# 25%        7.000000
# 50%       11.000000
# 75%       14.000000
# max       79.000000
# Name: text_len, dtype: float64

# %%
show_text_len(dev_anger).describe()
# Out:
# count    84.000000
# mean     10.500000
# std       4.280806
# min       2.000000
# 25%       6.750000
# 50%      11.000000
# 75%      13.000000
# max      21.000000
# Name: text_len, dtype: float64

# %%
show_text_len(dev_fear).describe()
# Out:
# count    110.000000
# mean      11.345455
# std        4.440093
# min        2.000000
# 25%        8.000000
# 50%       11.000000
# 75%       14.750000
# max       24.000000
# Name: text_len, dtype: float64

# %%
show_text_len(dev_joy).describe()
# Out:
# count    79.000000
# mean     10.468354
# std       4.044101
# min       2.000000
# 25%       8.000000
# 50%      10.000000
# 75%      14.000000
# max      23.000000
# Name: text_len, dtype: float64

# %%
show_text_len(dev_sadness).describe()
# Out:
# count    74.000000
# mean     11.635135
# std       4.838698
# min       3.000000
# 25%       8.000000
# 50%      12.000000
# 75%      14.750000
# max      30.000000
# Name: text_len, dtype: float64

# %%
show_text_len(test_anger).describe()
# Out:
# count    760.000000
# mean      11.240789
# std        4.980454
# min        1.000000
# 25%        8.000000
# 50%       11.000000
# 75%       14.000000
# max       43.000000
# Name: text_len, dtype: float64

# %%
show_text_len(test_fear).describe()
# Out:
# count    995.000000
# mean      11.056281
# std        4.710839
# min        1.000000
# 25%        8.000000
# 50%       11.000000
# 75%       14.000000
# max       38.000000
# Name: text_len, dtype: float64

# %%
show_text_len(test_joy).describe()
# Out:
# count    714.000000
# mean      11.145658
# std        5.262380
# min        2.000000
# 25%        7.000000
# 50%       11.000000
# 75%       14.000000
# max       42.000000
# Name: text_len, dtype: float64

# %%
show_text_len(test_sadness).describe()
# Out:
# count    673.000000
# mean      11.087667
# std        4.508891
# min        2.000000
# 25%        8.000000
# 50%       11.000000
# 75%       14.000000
# max       27.000000
# Name: text_len, dtype: float64

# %% [markdown]
# There is not any reviews' length = 0 after text cleaning

# %%
train_anger_tweets = list(train_anger['Tweet'])
train_anger_intensities = list(train_anger['Rating'])

train_fear_tweets = list(train_fear['Tweet'])
train_fear_intensities = list(train_fear['Rating'])

train_sadness_tweets = list(train_sadness['Tweet'])
train_sadness_intensities = list(train_sadness['Rating'])

train_joy_tweets = list(train_joy['Tweet'])
train_joy_intensities = list(train_joy['Rating'])

# %%
# check
train_anger_tweets
# Out:
# ['how fuck who heck moved fridge knock landlord door angry mad',
#  'so indian uber driver called someone word if moving vehicle would jumped disgusted',
#  '<user> asked parcel delivered pick store address fuming poor customer service',
#  'ef whichever butt wipe pulled fire alarm davis bc sound asleep pissed angry upset tired sad tired angry',
#  'do join <user> put phone talk rude taking money acc willy nilly fuming',
#  'my blood boiling',
#  'when still got whole season wentworth watch stupid cunt work ruins us loudly crying face loudly crying face <user> raging old cunt',
#  '<user> tracking show equipment delivered why service suddenly delayed we already <number> weeks fuming',
#  '<user> legit furious people fucking idiots',
#  'how suppose work wtf dude thanks pissing',
#  'im mad power rangers im incensed im furious',
#  'wont use using <user> <user> these guys cant get nothing right fuming',
#  'bitches aggravate like inspires biggest cunt known man kind',
#  'why <user> come glasgow night working fucking gutted waiting appearance ages raging',
#  'fuking fuming face with steam from nose',
#  'zero help <user> customer service just pushing buck back forth promising callbacks happen anger loathing',
#  '<user> mention gra guy stops let <number> ppl front go wtf my blood boiling',
#  'hate lawn mower if soul would condemn fiery pits hell',
#  'people offended kendall ends photo shoot like seriously shut fuck',
#  'block everyone everywhere posting storm think everyone aware damn rain quit damn',
#  'making buddy cry bitch wait revenge hugging face ok hand light skin tone',
#  'be you tell true blooded hoop junkie switch fuck <user> team juz destroyed team you juz insult',
#  'got no response rate customer amazon disappointed face disappointed face why understand always amazon fault carrier fault',
#  'tasers immobilize taser someone fuck need shoot one second later this really sick rage fuck murder',
#  '<user> <user> <user> the way blood boiling little bastards',
#  'actually fuming nothing wear saturday',
#  '<user> straight people even arse straight guys think means threesome fine angry fuming',
#  'bloody parking ticket unam used face money with wings fuming',
#  'you ever find people around really irritate sometimes that right unam used face',
#  'get angry people know stop sign francis foster road',
#  'this fuck boiling inside gonna good let',
#  '<user> <user> wow my bill <number> <number> hav text prove taken <number> wines fuming con',
#  'blame whole season natalie the season would different turned back alliance pissed',
#  'since update <user> loses power nearly <number> faster furious',
#  '<user> fly fit rage fair',
#  'unbelievable takes <number> minutes get <user> fault call hangs fuming treat customers fairly',
#  '<user> <user> we blaming <number> fucking idiots putting world middle tantrums you one',
#  '<user> people infuriate',
#  '<user> mine party decide party slowly transformed vengeful hell cult white male resentment',
#  'so angry <user> order <number> months ago placed order <number> card billed never received disappointing',
#  'still log fucking snap chat snap chat snap',
#  '<user> sam yes not helpful we need sorting asap you keep promising stuff happen fuming',
#  'someone let snakes in my house bet it <user> kill that bugger when get my hands on him rage huck fp <number>',
#  'ef whichever butt wipe pulled fire alarm davis bc sound asleep pissed upset tired sad tired angry',
#  'why <user> come glasgow night working fucking gutted waiting appearance ages',
#  'feel furious',
#  'some mexican ladies irritate fuck outta have lil preschool fucking kids welfare amp all ll at smh',
#  'still log fucking snap chat snap chat',
#  'blame whole season natalie the season would different turned back alliance pissed bitter',
#  'people irritate mf soul',
#  'im angry face with tears of joy upside down face',
#  'people fuckin irritate',
#  '<user> cruel cruel man there will be blood revenge',
#  'that way ur angry literally feel ur blood boiling',
#  '<user> amount greedy mooching makes snarl',
#  'my mind raging want end',
#  'absolutely fuming woman jumped pre booked taxi drove pouting face',
#  'nothing hateful bitter fag',
#  '<user> something needs done people hogging machines nobody use <number> machines one time angry not fair why pay',
#  '<user> ikr people still got grudge reason like fuck',
#  '<user> said talking wills uncontrollable animals moving another link these comments help fuming',
#  '<user> <user> bad news ordered online gone happened order phone furious',
#  'so angry wanna cry crying face crying face crying face',
#  'oooo ooooh my god uuuugggghhhhhhhhh',
#  'boycotting <user> till butter pecan comes back furious',
#  'in <number> black people still fighting recognized human beings cant sleep angry',
#  'mom cut phone furious hugging face',
#  'once thing feed na ay raging something brother filling gaps',
#  'believe achilles killed angry',
#  'lost couple niggas want revenge put coach',
#  '<user> poor packaging amazon fulfilled seller furious much confused face',
#  'where outrage black man kills another black man streets',
#  'makes fucking rate jesus nobody calling ppl like hajime abusive stop strawmen lmao',
#  'absolutely fuming scratched car pouting face pouting face pouting face pouting face pouting face pouting face',
#  '<user> holy shit bee sting like fuck dying',
#  'how fuck who heck moved fridge knock landlord door mad',
#  'dislike people get offended littlest shit',
#  'what fuck supposed lunch dinner money work furious angry day <number>',
#  '<user> one person ruins season <number> angry',
#  'what fuck supposed lunch dinner money work angry day <number>',
#  '<user> buses unreliable ticket app unable get two buses late work fuming useless reply',
#  'so indian uber driver called someone word if moving vehicle would jumped disgusted offended',
#  'the liberal outrage king saying word really angers the white yuppie progressives go fuck shame blacks',
#  'just paid chicken <user> even get expressionless face expressionless face expressionless face goes <number> dollars customer angry',
#  'mistake half assed excuse burning hell forever',
#  '<user> years irrelevant its absolute joke man utd ticketing fuming no loyalty joke not impressed',
#  '<user> part <number> buzzing cheeky squash ie two not expected sort it out food angry <user> <user>',
#  'tasers immobilize taser someone fuck need shoot one second later this really sick fuck murder',
#  'be you tell true blooded hoop junkie switch fuck <user> team juz destroyed team you juz',
#  '<user> fucked coupon goal raging',
#  'lvg bribed refs utd personal revenge that foul prick',
#  'now whole clown rage scared shitless gonna go cry room',
#  'worst juror ever michelle you nicole biggest threat bitter bb <number>',
#  'your twitter picture makes fume',
#  '<user> cruel cruel man there will be blood',
#  'that really madden career game sucks ea sports piss poor job every year shit',
#  '<user> <user> ha right san jose ca offended right dave go walk something next time',
#  '<user> something needs done people hogging machines nobody use <number> machines one time not fair why pay',
#  'wonder american city next protest police shootings who next smh when will its top angry how many more times',
#  '<user> <user> another angry white man',
#  'have wee pop socks keep falling off inside my shoes rage',
#  'the majority people irritate fuck cba people ahahah',
#  '<user> multimillionaire spoiled brat gets in self righteous huff bc friend muslim non starter bye',
#  'wont use using <user> <user> these guys cant get nothing right',
#  '<user> provoke anger',
#  'you complain time wonder people never want see you acc rile stfu uu',
#  'bloods boiling',
#  'leave rule imber <number> carpet cleaning furious worse than an atomic bomb accidently spill beer on the carpet',
#  '<user> wallah blood boiling need take nap ugh',
#  'swear <user> blocks going hit back',
#  '<user> angry student racist teacher stopping class letting go',
#  'block everyone everywhere posting storm think everyone aware damn rain quit damn rage',
#  'fuming ball anger today upside down face',
#  'find till today due bff telling disgusted offended',
#  '<user> thanks saying my wife getting phones today losing eta thanks angry',
#  '<user> turning why surprised late work fuming',
#  'police officers not right hoot human beings without provocation it wrong <user> <user>',
#  'angry already',
#  'flat party instantly get bol locked fuming',
#  '<user> add tracking resent',
#  '<user> <user> <user> this man affront justice system',
#  'someone let snakes in my house bet it <user> kill that bugger when get my hands on him huck fp <number>',
#  '<user> ummm blog says simon stehr faking <number> th expect investigation forthwith this outrage',
#  '<user> black armed thug record carrying gun illegally gets shot black cop outrage this joke let em destroy town',
#  'wakes says tried changing nappy pouting face oncoming fist medium light skin tone rage',
#  'someone needs tell candice stuck shitty pout wind changes gb bo',
#  '<user> turn shit home button accessibility when innovation become mind fucker phonephone home',
#  'love people make plans without actually including process rage',
#  '<user> smh remove ideologically bankrupt opportunistic establishment they burning bridges social contracts anger',
#  '<user> outrage party nominated lying corrupt person and received donations nations support terror',
#  '<user> even forget pick ur fave child school offended',
#  'get angry people know stop sign francis foster road rage',
#  '<user> irritate them inch thick made masks',
#  '<user> fucked coupon goal',
#  'how natalie one top three favorites too faced bitter face with rolling eyes',
#  '<user> democrats voters zero tolerance honesty they associate honesty anger hate',
#  '<user> rage the crooked court said rage many times explain away brutal killings petits hayes amp komisar jev sky',
#  'to why brothers protect one another no one serious makes furious do misled think fred mayfield',
#  'wakes says tried changing nappy pouting face oncoming fist medium light skin tone',
#  '<user> years irrelevant its absolute joke man utd ticketing no loyalty joke not impressed',
#  'all hell breaking loose charlotte charlotte protest anger looting',
#  'there bpharm <number> guy ish guy brings anger life when see nje like darkness fills <user> know',
#  'hour football practice boiling sun <number> hr volleyball practice boiling sun again',
#  'testing angry',
#  '<user> <user> put much artefact points fury cant raid literally wasted <number> month life thanks blizzard',
#  'how suppose work wtf dude thanks pissing furious',
#  'angry',
#  'that feel travel <number> miles pick form arrives post two days leave fume',
#  '<user> congratulations free <number> month activated then charges <number> <number> month absolutely furious pouting face',
#  '<user> <user> hell hath fury like women scorned it affair not parenting',
#  'straight people ca noodling quad offended',
#  'definitely feel irritation today lord give strength',
#  '<user> chelsea anything possible haha fuming bet face with rolling eyes face with rolling eyes face with rolling eyes face with rolling eyes face with rolling eyes face with rolling eyes',
#  'when break record madden wish say shit every rush like broke record shut up phil simms',
#  '<user> apparently contact sofas meant delivered today old ones gone sitting floor no sofas fuming',
#  '<number> rabid grizzly bears going scatter neighborhoods america they poor refugees in your neighborhood not dc',
#  '<user> dont blm thugs want justice black black gang crime they rage cry racism cop',
#  '<user> honest hope annoying southern bint look pout goes week se las ftw',
#  'zero help <user> customer service just pushing buck back forth promising callbacks happen loathing',
#  '<user> stupid hate lol bitter',
#  '<user> joke cut internet early mistake reinstate longer need engineer pouting face',
#  '<user> <user> yeah received fine today furious currently appealing member long',
#  'people irritate face with rolling eyes',
#  'men rage strike wish best rage emotions negative positive wish strike martial arts control believe best hope',
#  'in <number> black people still fighting recognized human beings cant sleep',
#  'swear <user> blocks going hit back revenge',
#  '<user> joke cut internet early mistake reinstate longer need engineer pouting face fuming',
#  '<user> <user> <number> unarmed blacks killed white cops <number> that many die every month chicago wheres outrage',
#  '<user> tracking show equipment delivered why service suddenly delayed we already <number> weeks',
#  'does really need pout time getting nerves gb bo',
#  'ever put fist laptops screen if time new one lmao rage anger hp',
#  '<user> <user> may be also attacked tom rabid fans amp clothes always perfect also put',
#  'dear future big brother players chase dick season win <number> <number> dollars sti bb <number> bitter',
#  '<user> <user> nobody street burning looting terrifying innocent citizens either',
#  '<user> not happy still charging full price pouting face pouting face fuming bestrides flushed face flushed face',
#  'forgot eat dinner furious everything everyone',
#  'girl sitting front chewing gum like cow amp im ready snap hugging face',
#  '<user> nonsensical if injustice blacks add destroying black property it misdirected anger',
#  'can someone make priority list things outraged order racism animal rights abortion cops',
#  '<user> <user> wow my bill <number> <number> hav text prove taken <number> wines con',
#  'you fuck boy run drag routes back back madden',
#  'got fever highs ni got boiling blood',
#  '<user> <user> bad temperament tantrums hissy fits',
#  'even right bb <number> rage',
#  '<user> <user> haha actually doggies bar racking anyone but gws bitter',
#  'why people phones bitter phones can someone explain',
#  '<user> the guy calls people uck anti blm offended idea might pro policing reform that amazing',
#  '<user> always unhappy easily offended',
#  '<user> shameful display watched today left reeling much anger dt feel like exploding clowns watch',
#  'all hell breaking loose charlotte charlotte protest looting',
#  'when still got whole season wentworth watch stupid cunt work ruins us loudly crying face loudly crying face <user> old cunt',
#  'half epicenter shut police burst tears fucking terrible keith lamont scott',
#  'not giving fuck better revenge',
#  '<user> get shit wrath winter nowhere',
#  '<user> why though why want offend americans',
#  '<user> <user> <number> unarmed blacks killed white cops <number> that many die every month chicago wheres',
#  '<user> think monalisa respect anyone think ruffle feathers the jail',
#  '<user> asked parcel delivered pick store address poor customer service',
#  'thought xbox one madden bundle would come physical copy madden code sleeping face gonna take fucking forever download lol',
#  '<user> <user> bad temperament hissy fits',
#  'my blood bitter satan test becouse cleanse blood jesus christ amen',
#  'the new gun moji ios <number> enough show anger towards number things',
#  '<user> jealous cry baby bitter glad she is gone crybaby',
#  'wanna know outrage black black crime one knows victims blm kill cops based media',
#  'forever angry gh ruined molly morgan bond friendship bitter',
#  'spurs radio commentator referred mauricio poche tti no mopo felt sudden surge rage',
#  '<user> <user> <user> huh we sprint coach we slowest team comp talk robbing living outrage',
#  'ca believe got <number> days left face with rolling eyes back to reality raging',
#  '<user> fuming',
#  'taking break wedding rage general stupidity certain people internet',
#  'ever put fist laptops screen if time new one lmao hp',
#  'my brother grabbed aggressive manner always <user> threw tantrums like kid knowing express',
#  'do join <user> put phone talk rude taking money acc willy nilly',
#  '<user> assure laughter increasing anger costs arrogance westminster',
#  'people need way escape escape this corrupted world this reality this joke this fury constant pain amp stress we need vacation',
#  'love black people really really but people really irritate living hell outta cause different expressionless face',
#  'talk politics people nowadays get offended easily',
#  '<user> <user> oh yeah hate air raid like oregon baylor offense fan ole miss one either',
#  '<user> received verification email asked resent <number> times still nothing',
#  'unbelievable takes <number> minutes get <user> fault call hangs treat customers fairly',
#  '<user> no justification shooting without provocation even person bad history justification way go',
#  'genuinely think anger issues',
#  '<user> im honestly offended',
#  'michelle one worst players bb history bb <number> bb finale bitter',
#  'annoyed sad youtube burning ground face with rolling eyes face with rolling eyes',
#  'how tell happy anniversary happy bitter amp alaya paitpaitanangpeg',
#  'just paid chicken <user> even get expressionless face expressionless face expressionless face goes <number> dollars customer',
#  'never forget <number> live cancelled programs allow extend <number> people could call detail outrage behaviour',
#  'when someone rudely says women long hair inner feminist tries rage',
#  'absolutely raging changes cas joke',
#  'girls irritate much lol',
#  '<user> waiting figure like <number> <number> real quick irritation',
#  '<user> listen yh provoke cos make cry',
#  '<user> did even give pizzas serious fail hungry furious angry',
#  'bloody parking ticket unam used face money with wings',
#  '<user> apparently contact sofas meant delivered today old ones gone sitting floor no sofas',
#  '<user> sam yes not helpful we need sorting asap you keep promising stuff happen',
#  'they like rape apologists inadvertently make men sound like rabid mindless beasts with friends like',
#  'and got angry telling would <number> year old guy looking girl like felt offended',
#  '<user> <user> shot black police woman typical looney toon thinking hillary divide chaos',
#  '<user> <user> <user> sex offense happens across all races cultures creeds amp castrated',
#  '<user> <user> prudence suggests <number> bump <number> <number> weeks viewed skepticism media hrc axis angry',
#  '<user> rabid dog ridden child eaten flesh one fellow limbs adults',
#  '<user> one thing attacking hating worse makes us like angry vengeful behavior detest',
#  'delete shit josh screenshot ted snap',
#  'can someone make priority list things outraged order outrage racism animal rights abortion cops',
#  '<user> <user> <user> true just spitting venom still bitter stripe like old man yelling porch',
#  'never watch greys anatomy ever ever ever ever ever shonda rimes takes away another og character frowning face frowning face frowning face frowning face frowning face frowning face frowning face frowning face frowning face frowning face fuming',
#  'wonder would happen tell people truth savage uh oh angry',
#  'you never find someone loved like and love revenge',
#  '<user> turning why surprised late work',
#  'if angry may case amp may unavoidable see sudden excitement become sin albert barnes',
#  '<user> hit even begin describe fiery little demons straight hell full moon face new moon face',
#  'bitter today neutral face',
#  '<user> <user> meanwhile white cops keep killing black people but less outrage strange society',
#  '<user> <user> team must draw hat daily personality drugged angry yeller quiet screamer face with tears of joy face with tears of joy',
#  'heading home cut grass heat all wanna go eat somewhere air conditioned pout adult ing is the worst',
#  'oooo ooooh my god uuuugggghhhhhhhhh rage',
#  'never watch greys anatomy ever ever ever ever ever shonda rimes takes away another og character frowning face frowning face frowning face frowning face frowning face frowning face frowning face frowning face frowning face frowning face',
#  '<user> <user> specific amp intentional way and part intention provoke conversation around systemic racism towards blacks',
#  '<user> gave kendrick lamar eat barbecue bitter',
#  '<user> said talking wills uncontrollable animals moving another link these comments help',
#  '<user> sorry angry drone flew away',
#  '<user> id fuming',
#  '<user> <user> shut hash tags cool offended',
#  '<user> know trusted his words soft ignored anger focused hurt beneath know screwed',
#  'wonder american city next protest police shootings who next smh when will its top how many more times',
#  'why mfs bitter',
#  'im holiday next round fuming',
#  'did miss fact burke ramsey swung amp hit sister jonbenet face golf club previously fit anger',
#  '<user> the point voting trump push pieces board game like angry toddler wreck everything everybody',
#  'like aggravate constantly by eeee eeee',
#  '<user> <user> rip <number> black men women children killed chicago where outrage',
#  'in pouring letter dying subsist checking quaint virtuoso ways toward fine huff',
#  'hitting children discipline quite raging hypocrite',
#  'sorry im bitter either want pure ur literally card sets like every time draw sets like gt',
#  '<user> what king says matter the fact came psycho don far affront',
#  '<user> bloody right',
#  'much hw tonight im offended',
#  'like hello first born must always laugh jokes offended',
#  'outrage passed replaced mute fatalistic acceptance current situation fatalism',
#  'have wee pop socks keep falling off inside my shoes',
#  'apparently supposed scottish accent offended',
#  'seek conduct attacks israel intended provoke reaction would inflame feeling within islamic world',
#  'lost frequencies janie ck devy reality gestor aber geil remix raging shout drive',
#  '<user> <user> miss outrage',
#  '<user> it eye eye indian army never for gives never forgets they always take revenge pakistan breaks laws follows',
#  'worst juror ever michelle you nicole biggest threat bb <number>',
#  'luv seeing man scowl face walking protein shaker clenching fists immediately stop suck dick',
#  'fake people irritate',
#  'said say america really fortunate black people want equality revenge',
#  'anger wrath intense emotional response',
#  '<user> <user> aa right passage comes word why insult church ignorant',
#  'let id fuming poor keeping',
#  '<user> yeah seen floated online theory probably made bitter stan ignore pets vets crap',
#  '<user> east wind blue summer durban africa still surfed got stung badly must carefull sting harm',
#  '<user> <user> <user> <user> everyone wigan biggest club bitter',
#  'because perfect illusion least know angry lady gaga is calming my soul',
#  'candace amp pout getting right tits gb bo',
#  '<user> <user> looking forward <user> then opened stuart special literally yelled tv',
#  'bang gordon brown accused abusing gazillion rabid parrots',
#  'petition non maghreb poc stop buying couscous white grocery stores boiling that couscous trash',
#  'espn assumed wanted free magazines offended',
#  'yo kid snap chat la amp get high helium gas lmao like fuck lol',
#  '<user> today proceedings entire process insult constituents',
#  '<user> <user> <user> sensing theme tho lol angry',
#  '<user> low key forgot twitter follow back im gonna offended',
#  'flat party instantly get bol locked',
#  '<user> like every color looks triggered colorblind offended',
#  '<user> straight people even arse straight guys think means threesome fine',
#  '<user> <user> <user> yes bad point racism lest provoke racists some racists indeed like',
#  '<user> <user> this left wanted play heavier game we needed offense tho amongst others',
#  '<user> <user> offended',
#  '<user> hello the bigger bully crocodile tears bullies always act like offended victims',
#  '<user> <user> irish citizens boiling drinking water <number> leaves one foot firmly bog',
#  'candice pout gonna take someone eye mate gb bo',
#  'always weird grudge stingrays ever since one killed steve irwin',
#  '<user> gotta use dark skin moji offended',
#  'saying might like big foot might like natural biological father says blood boiling cross',
#  'really really resent go bed sensible hour guys want to talk to my people',
#  '<user> incentivise people roam internet morally offended enough already',
#  'that person trademark get bitter seeing ravi stans',
#  '<user> amen nothing personal mate tired complaining fans been relentless tirade misery',
#  'michelle one worst players bb history bb <number> bb finale',
#  'dear indians it hard swallow try swallow bitter pill pakistan number one test cricket',
#  'little nose irritation little chills body flu flu flu fall songs',
#  'real sjw let america ni found us go get us ni let let ni rage lol <user>',
#  'connive rs blind existential fury',
#  'guys irritate',
#  'first tweet ever sippin hot chocolate wondering finally gave lt <number> haha hell lo oooo twitter facebook is for family rage',
#  '<user> directing anger thieves government corruption fees must fall',
#  'need new outlet rage',
#  '<user> ive denial anger pure acceptance',
#  '<user> timid determined version rabid beasts beyond land growling beneath restrained breath rip',
#  'used pretty girls use curse words express anger feel like little bit surprised turned well',
#  '<user> huff puff',
#  'hell hath fury like hamstring cramp ouch',
#  'actually arsed sister sometimes controls tv <number> time watch one thing gets huff face with rolling eyes',
#  '<user> first exp ac since wrath feels like proper evolution game',
#  '<user> happened suicide tweet joke obviously could offend anyone thinking face',
#  '<user> relentless echo chamber negative comments lots reverb typical bully behavior',
#  'find initiative even thing anguished face revenge',
#  '<user> jojo <number> <number> midnight lets rage wry yyyy',
#  'happily rude people personally insult unprovoked deserve thumbs up just good people deserve respect',
#  'that ak <number> leave spine frown',
#  'come let make em hate face blowing kiss make em pout face angry face with horns weary face',
#  'recommended reading prisoners hate aaron beck anger',
#  '<user> snap meee',
#  '<user> resent',
#  'forever angry gh ruined molly morgan bond friendship',
#  'disgraceful es in resent men way reason sins countdown',
#  '<user> acc ide tly dumped boiling water tired face',
#  '<user> smh remove ideologically bankrupt opportunistic establishment they burning bridges social contracts',
#  'as usual disappointing offense <user> texans',
#  '<user> stupid hate lol',
#  '<user> irritation found corpse',
#  'never make decision angry gt lt never make promis happy',
#  '<user> both trump king relentless self promoters give rip anyone else perfect match donalds',
#  '<user> <user> cancelled cbs access live feeds jc even said vic afp paul imo bitter',
#  'whenever put wanna adored brother always sings wanna dog instead irritate',
#  '<user> <user> looking forward <user> then opened stuart special literally yelled tv umbrage',
#  'get point made reporting charlotte looting <user> why explore looting businesses symbolizes outrage',
#  '<user> taking feelings kei unfairly his lips form frown tries walk away',
#  '<user> left dad deal face with tears of joy my work done soon felt wrath slipper face with medical mask',
#  'leave rule imber <number> carpet cleaning worse than an atomic bomb accidently spill beer on the carpet',
#  '<user> yikes the wrath maddie',
#  '<user> <user> think came back twitter ruffle bushes tuh',
#  '<user> <user> insult sounds like job well done red done job suppose just saying',
#  'hud comedy adam rowe insult slut faces long nugget',
#  'need help anger',
#  '<user> never bring back meech bridgette crying someone looks ugh bridgette bitter',
#  'hey folks sorry anything offensive got posted yesterday account got hacked all fixed though hope annoyed',
#  'now time remove cb team somehow screw rip band aid it sting bit everyone get',
#  'candice pout gets preposterous week this week gone bit jack nicholson joker gb bo',
#  '<user> unfortunately end followers whichever candidate elected throw tantrums no winning elec',
#  '<user> <user> team must draw hat daily personality drugged yeller quiet screamer face with tears of joy face with tears of joy',
#  'candice standing pout face aggravates every week',
#  'think really broke young bull hurt face with tears of joy face with tears of joy loudly crying face loudly crying face tell bitter mad smiling face with smiling eyes smiling face with smiling eyes weary face weary face',
#  '<user> yuu uhh face with rolling eyes loudly crying face plus clin ep prev med ugg hhh hahaha bitter',
#  '<user> time man got paid throw temper tantrums speaks gotta listen',
#  'as heard thought ether ex posted facebook pic snuggling said cats im angry',
#  'provoke letting',
#  'could never angry drunk lol yall weirdos enjoy time',
#  'yet still deaths road rage amp violations road despite widely accepted concept personal accountability driving',
#  '<user> oh good god quentin letts one comedy turns angry <user> <user> bbc tw',
#  '<user> looks completely rabid <user>',
#  'inner conflict happens odds honor values priorities inner conflict conflict values',
#  'epipen public outrage occurs expand pap patient assistance progr coupons rebates <user> <user> mylan epipen',
#  'imagine twitter fume corbyn loses election smith leads labour worse result suggested corbyn imagine',
#  '<user> scared ruffle feathers resorted writing cryptic code uncle cams cabin',
#  'did think cadres getting src deployment would make cadres bitter ku tough macom',
#  'miss nothing someone care attacking face kisses forever alone bitter weary face',
#  'that grudge holding keeps making appearance god wants deal',
#  '<user> <user> <user> <user> <user> comparing akshay sir zand balm insult akshay sir',
#  'fire anger acid harm vessel stored anything poured fire anger mark twain',
#  'if spend <number> shimmy <number> drinks raging know gonna happen',
#  'rage rage ep <number> coming soon keep posted youtube youtube gaming rage',
#  '<user> gender bias indignant this fancy pants saddler daughter opt leather jacket thank much',
#  'when sister <number> throws legitimate temper tantrums get attention',
#  '<user> did even give pizzas serious fail hungry angry',
#  'this provocation sets curiosity an entity feeding fuel fire speaking quatrains hmmm america needs vigilant',
#  '<user> <user> quite response retaliation weiner getting revenge huma amp hillary clam digging all scumbags',
#  'guess brad angelina gt anger gt black lives matter',
#  'now ex number time prank revenge prank what prank should do seriously prank',
#  'do despise lord discipline resent rebuke lord disciplines loves proverbs <number> <number> <number>',
#  'guy across really ugly suit can not stop expressing displeasure',
#  'some moving clips youtube tonight vigil held tulsa metropolitan baptist church terence ruther justice anger sadness',
#  'think must scare coworkers eating like rabid animal breaks srry',
#  '<user> bloody right fume',
#  '<user> roy fiery',
#  'why puerto rican taino hair black nose gotta ruffle targeted feathers',
#  '<user> <user> prudence suggests <number> bump <number> <number> weeks viewed skepticism media hrc axis',
#  'listening joey really helps anger',
#  '<user> anger issues',
#  'believe messing favourite bakes feel personally offended',
#  'think may offended',
#  '<user> <user> would give pout firm',
#  'using twitter coping mechanism raging kid oops',
#  '<user> believe call fury righteous',
#  'ok got called white devil train didnt know whether laugh offended',
#  'india take revenge making <number> new movies like phantom like husk mar enge indian army take revenge',
#  '<user> wouldnt date offended',
#  'drop snap chat names bored snap swap pics',
#  'damn offense mix bag unpredictable lethal weapons worried defense coordinators beaming face with smiling eyes chargers bolt up recharged',
#  'bee sting still suck feel sick',
#  'love people make plans without actually including process',
#  '<user> offended actually',
#  'pressure burst pipes loudly crying face',
#  '<user> learn <user> viral insult ballet stop trying wrongfully stick models pointe shoes face with rolling eyes',
#  '<user> no sense taking wrath innocent people think police shot innocent man make america safe again',
#  '<user> <user> sorry offend griffin',
#  '<user> indignant wants world knows obama nothing put in wants aleppo syria',
#  '<user> even beef sara let anger get best sag in friends long',
#  '<user> <user> <user> fuckin luv incense fuck face with tears of joy',
#  'screened snap kind narcissistic ass would smh',
#  'even feel anger anymore explain tulsa charlotte tray von sandra bland phil an do ferguson baton rouge michael brown',
#  '<user> <user> doll vile creature touchline every game tantrums amp shouts ref would love see',
#  '<user> gotta use dark skin moji',
#  'jamming fury math class wanting die hbu',
#  'so wished sis <number> midnight received reply my <number> nd sis just wished got reply you know fav offended',
#  '<user> im writing abt changing face sex industry tr men talk revenge',
#  'believe achilles killed',
#  '<user> hah speak cousin like mind displeasure seeing bare faced eh train pretty sight mate',
#  'indignation whispers date terrific lerman letts centerpiece scene that overwhelming sense indignation',
#  '<user> never bring back meech bridgette crying someone looks ugh bridgette',
#  '<user> some people would rather hang indignant anger weary sigh',
#  '<user> thanks saying my wife getting phones today losing eta thanks',
#  'that moment watching worst celebrity cooks bubble burst finding kyle xy gay married loudly crying face no chance kinda dont mind winking face',
#  'women like girls resent looking great wish still looked like washed',
#  'hey folks sorry anything offensive got posted yesterday account got hacked all fixed though hope angry annoyed',
#  '<user> then understand rage often pretty controlled rational often visceral always logical',
#  'my leg feels like gonna burst yet still expected go work',
#  'the best revenge move get continue succeed never give someone satisfaction watching suffer',
#  'get work fire drill fire out there in the dark',
#  '<user> lt feel everything she would remember everything evan or hoped would serve fuel creatures anger run rabid gt',
#  '<user> exactly saying fb bitter',
#  'get work fire drill fire burning out there in the dark',
#  '<user> <user> turned rather fiery gg radical',
#  'significantly bitter smile let',
#  '<user> true none players cops do drink chilled bitter are players walter mitty types <user>',
#  'brendan rodgers looks fuming loudly crying face',
#  '<user> ummm blog says simon stehr faking <number> th expect investigation forthwith this',
#  'my baskets better bad mood someone irritate practice please',
#  'be chill af want offend someone',
#  '<user> <user> good thing fbi offend',
#  'know cyr an still done make up based jeong guk tidd like suggested offended',
#  '<user> tyson fury beat man top years danny garcia bradley acqua io frampton',
#  'so wished sis <number> midnight received reply my <number> nd sis just wished got reply you know fav',
#  '<user> surprised would fuming face with steam from nose',
#  'oh old things face nah tears school related anger frustration nope never',
#  'british humour offend challenge mainstream views hat clarke son the ultra left go kneel allah',
#  'need attention if pout',
#  '<user> like half expecting rabid troll come mentions accusing csa apologist something lmao',
#  'because perfect illusion least know lady gaga is calming my soul',
#  'puzzle investing opening portland feo dal population correlative straight snorting infuriate xlzjyhg',
#  '<user> gives frustrated growl stepping closer putting gun barrier no alarms nothing happened he',
#  '<user> seriously dude buy bubble tape phones snap broke another phone',
#  'when forget mention bought dream boys tickets face with rolling eyes face with tears of joy raging',
#  'now <user> snap chat back constant battle see get ugliest snap one another face with tears of joy upside down face snap survival',
#  'nick said territorial growl someone gets close he san animal',
#  'mean offend anyone <number> <number> literally blames everything white people in cases true lot times',
#  'he totally knew trump finally gets revenge son law prosecution imprisonment throws christie bus',
#  'inner conflict happens odds honor values priorities anger inner conflict conflict values',
#  'are belittling kitty straight service provoke lift aboard wyc elv',
#  '<user> <user> played game john elway sacked <number> fumbled <number> is john elway know madden',
#  'and got angry telling would <number> year old guy looking girl like felt',
#  '<user> next series celebrity firefighting show chuck burning building voice over',
#  'like <number> hours worth standing calorie burning <number> hours loudly crying face loudly crying face loudly crying face loudly crying face <number> st world probs <number> vs',
#  'before revenge feel good revenge feel worse hundred points <user>',
#  'wonder would happen tell people truth savage uh oh',
#  'take public opinion revenge pakistan govt unable decide <user> <user> <user>',
#  '<user> wouldnt date',
#  'teams face barca bayern defeat ones face wrath',
#  'understand everyone angry want live thrive',
#  '<user> hell hot boiling isi ewu',
#  'welfare reform model snap',
#  '<user> yeah gotta make heel know need votes wait but lose really wrath',
#  'well <user> trump rabid base needs <number> hear amp always find overseer like king say <user> <user> <user>',
#  'skipping meals national way showing disappointment anger wiz',
#  'streets rage <number> hard find itunes stepped guys vinyl made simple',
#  '<user> <user> bad news ordered online gone happened order phone',
#  '<user> my heart left long slight pout turned smile heheh kidding fine',
#  'people angry toward veggie burgers fuck',
#  'mean done watching pilot nice see group actors perform without story lines dripping relentless nihilism',
#  'checked flight toronto took seat <number> infuriate <user>',
#  'egyptian officials expressed frustration outrage obama hillary administration support muslim brotherhood',
#  '<user> <user> tiff better hurry cause eyes',
#  '<user> it buzzing pathetically sympathy let twirl moustache chuckle sting psycho wasp',
#  'matt psychological study provocation abusive relationships',
#  '<user> no greater wrath woman scorned',
#  '<user> might get donal sure they cork fiery dopey frank amp cult',
#  '<user> curious mean no rush animosity disdain',
#  '<user> best revenge get good woman move leave hairline figure alone',
#  '<user> talking expansion gear fury always well towards end',
#  'who knew softballs could sting bad jimmy fallon lot heat amp ldquo softball amp rdquo donald trump interview',
#  '<user> yuu uhh face with rolling eyes loudly crying face plus clin ep prev med ugg hhh hahaha',
#  '<user> would furrow face would redden protests would seem seen unattractive wu kong eyes',
#  'finding two best fwend going rage <user> makes last week sleep extra worth',
#  'paul forever paul paul played better game bb <number> angry',
#  '<user> yep lol',
#  '<user> <user> found express yall displeasure winking face',
#  '<user> <user> got wind men for choice infuriate just makes sad generation',
#  'since update <user> loses power nearly <number> faster',
#  'the sun literally burning skin',
#  'that feel travel <number> miles pick form arrives post two days leave',
#  '<user> <user> <user> <user> <user> how chop feel you still feel sting looks brutal',
#  'chris ate mac cheese imma eat taffy',
#  '<user> just help maintain boost status world class centre education culture tolerance outrage',
#  'chris ate mac cheese imma eat taffy revenge',
#  'it weird discussing sex resentment confusion thing writing last night',
#  'as heard thought ether ex posted facebook pic snuggling said cats im',
#  'paul forever paul paul played better game bb <number>',
#  '<user> jealous cry baby glad she is gone crybaby',
#  '<user> <user> peter radio piece ball pure class digs revenge total balanced pro clapping hands clapping hands clapping hands',
#  '<user> <user> cancelled cbs access live feeds jc even said vic afp paul imo',
#  'the best revenge move get continue succeed never give someone satisfaction watching suffer',
#  '<user> <user> lol happy negative realistic ass self sorry offend',
#  '<number> tierney reaches deep cross back post plays back across alloa defence clear celtic relentless',
#  'ca believe got <number> days left face with rolling eyes back to reality',
#  '<user> look rabid',
#  '<user> blm outraged shooting nc day turns guy pointed gun police wait facts outrage',
#  'get embarrassed slightest things fret day hate',
#  '<user> <user> <user> relentless pipe thirst sheltered',
#  'get point made reporting charlotte looting <user> why explore looting businesses symbolizes',
#  'taurus react angrily take provoked longer',
#  '<user> seems like fight ready rage',
#  '<user> leafy roast pokemon go kid outrage means relevant mean kisses',
#  'think paul bitter pastry',
#  '<user> see think dumbed simplified offense br is set he comes complicated system',
#  'after becoming boiling hot slowly melting heart frozen',
#  '<user> <user> shut hash tags cool',
#  '<user> fury road',
#  'realizing holding grudge long immaturity wisdom',
#  '<user> that disappointment he fakes pout starts chuckle',
#  'some moving clips youtube tonight vigil held tulsa metropolitan baptist church terence ruther justice sadness',
#  '<user> grasp cobalt woman fairly easily fair cheeks would ignite fiery hue warm',
#  '<user> directtv best apparently sit silent anger do press say anything',
#  'believe women fiery month go struggle struggle develops strong character',
#  '<user> low key forgot twitter follow back im gonna',
#  'im also definitely still bitter yellow ranger asian asian representation hollywood essentially shrug anyway',
#  'did miss fact burke ramsey swung amp hit sister jonbenet face golf club previously fit',
#  '<user> oh dear watch woman pout well',
#  'life tip <number> know unresolved anger likely cause problems several areas life must recognize amp properly deal',
#  '<user> it like burning rap albums buy first gosh darn get rid',
#  '<user> unleashing god wrath cain',
#  '<user> little prick sting come tennessee get <number>',
#  '<user> <user> <user> dis dat nigga fume right',
#  'projection perception see someone else you also level within anger worry',
#  '<user> <user> <user> hey jayme were ear ear burning cuz talking beaming face with smiling eyes are going tomorrow',
#  '<user> one favorite songs brother real talk rage',
#  'controlling anger sign righteous people promised paradise quran surah al imran verses <number> <number> reward good deed',
#  '<user> gave kendrick lamar eat barbecue',
#  '<number> playing antichrist <user> play hustle outrage',
#  '<user> blame broken madden year',
#  '<user> <user> no offense way makes sense work magazine otherwise apologizing <number>',
#  'nahh hhhh <user> snap story got bussing face with tears of joy face with tears of joy face with tears of joy face with tears of joy face with tears of joy face with tears of joy face with tears of joy face with tears of joy face with tears of joy face with tears of joy face with tears of joy face with tears of joy face with tears of joy face with tears of joy',
#  '<user> with frown let distraught garde voir saying wishes trainer',
#  '<user> let rage',
#  'if could get line block germantown broncos lil league pop warner broncos usa football lineman',
#  '<user> but arms focused rage overpowered getting nerfed it still stronger fury though',
#  '<user> <user> <user> pretty average klitschko fury <number> joshua white <number>',
#  '<user> they still using offense middle <number> amp punt',
#  '<user> lol love aggravate juan keep good work lol',
#  '<user> tonight legit wait rage sign of the horns light skin tone sign of the horns light skin tone sign of the horns light skin tone sign of the horns light skin tone sign of the horns light skin tone fire',
#  'seeing rip shawty lo got thinking bout rappers thought <user> dying burst tears smh',
#  '<user> <user> <user> he looks especially lovely sadly removes potentially indignant mr convo',
#  'momma irritate asking questions like gone face with steam from nose',
#  'the bubble officially burst <number> boys beat trophy glory wpt main bye',
#  '<user> <user> haha actually doggies bar racking anyone but gws',
#  '<user> trouble feigned anger gave look told be have he knew would though one',
#  '<user> fans insult',
#  'offend',
#  'np rum rage',
#  'some bloke train obviously trying provoke west ham fans loudly slagging stadium mate phone',
#  'welfare reform model',
#  '<user> <user> <user> agree offense ass second half td score first drive',
#  '<user> paul furious <number> wait',
#  'trump is likewise rests bed racial resentment made knowingly intentionally long trump got politics',
#  'if let general tweet offend definitely twitter',
#  'as lives order complete amazing life journey successfully bitter',
#  '<user> yep lol bitter',
#  'straight people ca noodling quad',
#  'remember guy got angry kept saying gary sanchez best baseball player world lmao',
#  'what kali kitten she asked frown curling fair skinned forehead showed scar cat <user>',
#  '<user> like every color looks triggered colorblind',
#  'my husband found rabid hockey fans like waited line <number> <number> window stickers sj nhl ahl hockey',
#  '<user> <user> also best assets offense rb wr long term have offense utilize',
#  '<user> low growl escaping oh oh',
#  '<user> papercuts sting stub ur toe last like <number> secs',
#  'wanting salty fries mcdonald since yesterday burning fingers eating bc shits fire fire fire',
#  'love megan raging kendall jenner photo sat like thinking face upside down face',
#  '<user> cam still rattled backlash received made black qb comment suffered wrath white america',
#  'because offended lies alexandria goddard mean deric friend anything else purely fish in expedition',
#  'really insult coz soccer lmao wow',
#  'what terrible thing see vision helen keller begin end mind stephen covey where are going',
#  '<user> <user> bitter nicole cory evicted',
#  '<user> <user> offend face with rolling eyes loudly crying face face with tears of joy',
#  'what terrible thing see vision helen keller begin end mind stephen covey where are going relentless',
#  'the bitter battle sweeter victory',
#  'resent biting tongue',
#  'you fight elephants wrestled pigs quote of the day',
#  'people often grudge others can not enjoy',
#  '<user> <user> sorry burst bubble never illusion see evil monkey face with tears of joy face with tears of joy',
#  '<user> well archie no offense kinda old',
#  'scored madden <number> vita <number> au today bloke know would happily paid <number> money mouth face ever bargain bargain it',
#  'now fret scuffs take scuffs come phone use wet handed drop toilet day',
#  'if du yell fire crowded theater burst flames it cool trick bu',
#  'congress acting indignant epipen pricing quite disingenuous since craft laws allow gouging',
#  '<user> <user> yeah actually supports tweet ed thread initially because article righteous indignation',
#  '<user> live event brock vs orton <number> saturday wwe network if needs wwe <user> <user> revenge',
#  '<user> even forget pick ur fave child school',
#  'grateful hungry people life hungry learn change grow help etc sure anybody better',
#  '<user> eh well sting vs cactus loser leaves wcw match bash beach lol',
#  '<user> dip boiling water',
#  'rage rage ep <number> coming soon keep posted youtube youtube gaming',
#  'when anger rises think consequences quote wisdom anger',
#  'new madden kicking litter in bin sign',
#  'going say rooney shadow former self want offend shadows ntf cvm ufc',
#  'when burst crying alone realize one truly knows unhappy really want anyone know',
#  'schneider lin taking revenge <number> fouls',
#  '<user> dude new madden <number> haha',
#  'angry glass vodka',
#  'one month til someone bday think time flaunt got something pretty awesome revenge',
#  'strong independant practical stop living world fantasy snap faster get used reality better',
#  'time wounds heels drunk jesus rt lol wisdom quote comedy self revenge hate time funny politics trump potus <number>',
#  '<user> turn grumpy frown upside you something next impossible today',
#  'know cyr an still done make up based jeong guk tidd like suggested',
#  'the important thing be strong hold anger thoughts',
#  'gotta wonder caller max listens show first place incense <user>',
#  'believe gonna start singing snap stories tractor switch little bit',
#  'testing current earth burst team',
#  'if luck rest fall goes anything like today think going like season best day ever magic work',
#  'also ppl love whole damn lot erica joanna tiff sir li harley anja rest gc bc ran char',
#  '<user> hurts much eat read somewhere marshmallows good bc soft irritate',
#  'do fret cool humans follow become instantly cool bot',
#  '<user> snap seems problem',
#  'burning last <user>',
#  'ca wait ninja turtle costume raging osu halloween smiling face with horns',
#  '<user> but even jumped hoop takes one rate netizen decide playing rules enough',
#  'the best revenge massive success frank sinatra',
#  'despite sharing neill article saddens gazza case seems fury sentence remark',
#  'need stop second guess go first thought go relentless',
#  'we worship your feet where wrath mercy meet nand guilty world washed by love pure stream graham kendrick',
#  'dear future big brother players chase dick season win <number> <number> dollars sti bb <number>',
#  'he slow anger better mighty and rules spirit takes city np <number> <number> bible verse pride anger',
#  'holding grudge someone stop blessings god learn forgive amp forget folded hands medium dark skin tone',
#  'why candice constantly pout gb bo lipstick unam used face',
#  '<user> haters taught hate shown love there good quote goes comment tiff treat',
#  'nor hell fury like woman scorned william congreve',
#  'that least <number> rd time balls burst games',
#  '<user> <user> face with tears of joy face with tears of joy oh zombie rage face with tears of joy',
#  'prayers amp protection brothers sisters fighting charlotte rage machines',
#  '<user> lol ed privileged exasperation bottled sold',
#  'finally made fury warrior guide let know thoughts',
#  '<user> im writing abt changing face sex industry tr men talk',
#  '<user> gonna kind community raids wrath machine drops',
#  'nurse practitioner look pretty bad no offense course thank really added spark positivity needed today',
#  '<user> turn frown upside buddy upside down face',
#  '<user> she could sense anger stirring within took hand as long stay together safe',
#  'apparently supposed scottish accent',
#  '<user> she jogging bit stay beside puffing cheeks huff time oh jeez jasper',
#  '<user> yes think held grudge',
#  'guess holding grudge best',
#  '<user> solution but assumptions media articles every venue causes animosity conversation',
#  '<user> <user> <user> <user> everyone wigan biggest club',
#  '<user> anyway found short scale today perfect purposes soft hands aggravate chronic tendonitis',
#  'gameday vs buford today at <number> <number> at home never been so excited revenge',
#  'tonight drag race allstars <number> episode gave me life ya as sss queens team alaska team katya revenge bwahaha',
#  '<user> exactly saying fb',
#  'wasp sting itchy',
#  'haired man strides close watches major flinches away reaction draws growl throat <user>',
#  'srry feelings offend hugging face',
#  'sorry burst bubble century anymore welcome <number> st century',
#  'even right bb <number>',
#  'asian tiger mosquitoes relentless more aggressive kind dealt kid',
#  'sometimes best motivations come proving wrong energy relentless motivational quotes',
#  '<user> would bring it touchy subject and people get way offended days',
#  'are lost fury fearing fail',
#  'need bento box sushi date rice ball <user> spaghetti olive guarded date cheese wedge <user> oncoming fist medium light skin tone rocky date pizza tiff',
#  'alarm clock ringing morning flatmate knocked door asked set anything fire burning alive',
#  '<user> gotta fast furious',
#  '<user> <user> remember tas gamedev program said temper tantrums class time lol',
#  'love tay amp tiff sitting house work upside down face',
#  'he slow anger better mighty and rules spirit takes city np <number> <number> bible verse pride',
#  '<user> oh gosh get <number> raging comments cruise fans die laughing',
#  'skipping meals national way showing disappointment wiz',
#  'strong hands moving firmly grope <user> thighs squeezing digging nails extract growl',
#  '<user> tried boiling em takes years',
#  '<user> know died would also burst crying from joy winking face',
#  '<user> <user> it always fun anger all old dudes rock roll',
#  'bitter hurts lmao oo',
#  'sometimes think british political landscape desolate look foaming wasteland us think ok',
#  'wise man told hold in grudge like letting somebody live inside head rent free',
#  'heading home cut grass heat all wanna go eat somewhere air conditioned adult ing is the worst',
#  '<user> love lizzy warren latest rage wall street',
#  'when forget mention bought dream boys tickets face with rolling eyes face with tears of joy',
#  'praying lord keep anger hate jealousy away heart sign maturity conciseness',
#  'my little sister sure hold grudge face with tears of joy face with tears of joy face with tears of joy',
#  '<user> lt steve feet feeling blush sting cheeks undress thank much snapped gt',
#  'one main things im <number> filling void empty bitter heart making everything wanted growing',
#  'snap music kept running traffic <number> <number>',
#  'when anger rises think consequences quote wisdom',
#  'never make decision angry never make promise happy wise words',
#  'keep mind we weak do insult people human',
#  '<user> watch videos like madden better',
#  'projection perception see someone else you also level within worry',
#  'so rangers celtic revenge',
#  '<user> ehhh guess want everyone ever burst laughing front face with tears of joy',
#  '<user> <user> it true reverse engineered drink it scientific method hear rage',
#  '<user> yesss apparently popular snap face with rolling eyes',
#  'when grown adult drink never drank assume raised around raging alcoholic want parts',
#  '<user> <user> played game john elway sacked <number> fumbled <number> is john elway know',
#  'zumba pi yo hi it sessions sweaty burning soooo ooo good missed out on summer bikini body but wintersun body will do',
#  '<user> <user> three ag in pout',
#  'anger cheap politeness expensive do expect everybody polite thoughtful thursday politeness',
#  'give someone power letting words offend',
#  'rt <user> need one back whole cd hard one rage flew rhyme flow <number> speak dollar',
#  'lot <number> would give ghandi road rage',
#  '<user> least character fast furious pumped adrenaline franchise but',
#  'how tell happy anniversary happy amp alaya paitpaitanangpeg',
#  'love <user> angry tweet bc makes laugh also hate bc makes miss',
#  'find initiative even thing anguished face',
#  'all cigarette burning laura hand angle chin purse lips <number> gorgeous transition <user>',
#  'this resent india pakistan problem save nawaz sharif <user>',
#  'awareness seek shelter let go old habit chasing desires result in anger fear worry choose satisfaction within peace relax',
#  '<user> wolfpack theme trons sting wore wolf shirt',
#  '<user> sadness resentment past sadness fear future try live mh chat',
#  'anger cheap politeness expensive do expect everybody polite thoughtful thursday anger politeness',
#  '<user> case raging moody cow lol buy moody cow socks lol',
#  'minding business grinding relentless <user>',
#  'holding grudge make strong makes bitter for giving make weak sets free',
#  '<user> regarde tes snap',
#  'standard candice starting show pout start as you mean to go on gb bo',
#  '<user> orange one poisonous bitter you judge blue one looks tastes delicious',
#  'who got madden <number> <number> <number> ps <number> add track dawg lets run',
#  'wish next madden story mode just like fifa <number> madden',
#  '<user> <user> taking offense count ranks <number> <number> last <number> years sabr',
#  '<user> thank justin amazing concert believe provoke thousand smiles night believe tour',
#  '<user> klitschko <user> fury day boxing',
#  'the best revenge massive success',
#  'tian gong <number> china first space laboratory come fiery end late <number> the average decommissioned satellite either burns',
#  'houston might lose coach tomorrow midnight yikes',
#  'well lines sweden goals sure sting',
#  'do get bitter get better',
#  'do bitter',
#  'went bodega <number> incense look sis behind counter amp like mirror said said said originally',
#  'recommended reading prisoners hate aaron beck',
#  '<user> joke know incense',
#  'leveled half much better offense expected second half',
#  '<user> <user> <user> huh we sprint coach we slowest team comp talk robbing living',
#  'first tweet ever sippin hot chocolate wondering finally gave lt <number> haha hell lo oooo twitter facebook is for family',
#  'one favorite classic cars plymouth fiery',
#  'as lives order complete amazing life journey successfully',
#  'kik want swap pics post account anonymously wish kik vs vp lou kik kik me snap nudes tits snap chat',
#  'focus do let love define happy let make bitter get hurt',
#  'wish next madden story mode just like fifa <number>',
#  '<user> frown cup cheeks hands step aside angela care and know else',
#  'flushed face the intensity <user> play extraordinary relentless afl cats swans afl finals rugby football clapping hands dark skin tone',
#  'need new outlet',
#  'need bento box sushi date rice ball <user> spaghetti olive guarded date cheese wedge <user> oncoming fist medium light skin tone rocky date pizza',
#  '<user> <user> <user> snap andria preble red heart',
#  'colors leaves changing heatwaves la still raging lattes made batches visit pumpkin patches fall songs',
#  '<user> ldf <number> shall weekend spray painting greenwich market <user> core <number> lily lou fret amp ben oakley',
#  'it takes man suffer ignorance smile be matter say',
#  '<user> meeee lvl <number> single relentless',
#  '<user> <user> ummm dragons fury though',
#  '<user> perfect but even way sort resent suspect leads double life just perfect',
#  '<user> thought peeped snap that homie raised fist medium skin tone lol',
#  '<user> <user> my heart goes woman indignity sitting',
#  'you fight elephants wrestled pigs quote of the day relentless',
#  '<user> <user> <user> sensing theme tho lol',
#  'espn assumed wanted free magazines',
#  'if luck rest fall goes anything like today think going like season best day ever magic work snap',
#  'these new england patriots jerseys look like whack ones tried make made custom jerseys madden <number>',
#  '<user> <user> no grudge only truth abundance',
#  '<user> take jk have fun relax get massage two chill do eat cucumbers places frown',
#  '<number> meeting olympic house <number> golds <number> never quit believe dream big team to going <number> gold',
#  'houston might lose coach tomorrow midnight yikes offense',
#  'it easy hold grudge harder let go',
#  'prayers amp protection brothers sisters fighting charlotte machines',
#  'testing',
#  'happiness best revenge',
#  'forgot nice area fiery hearths',
#  'it takes man suffer ignorance smile be matter say sting',
#  '<user> also madden funniest game watch much happening boring',
#  'mm okay ham turkey gives hair ruffle heading back kitchen set gt gt <user>',
#  'oh watching rage it like ages',
#  'like hello first born must always laugh jokes',
#  'sometimes best motivations come proving wrong energy motivational quotes',
#  'tonight drag race allstars <number> episode gave me life ya as sss queens team alaska team katya bwahaha',
#  'naoto nod also like tha bands also frown will bands papa roach concert',
#  'if someone keeps laughing fret at least giving happiness quotes quotes to live by',
#  '<user> sounds like good game plan offense',
#  'the important thing be strong hold thoughts',
#  'so rangers celtic',
#  'think may',
#  'really study today chemistry playing madden way fun',
#  'love word fret much im heaven',
#  '<user> live event brock vs orton <number> saturday wwe network if needs wwe <user> <user>',
#  'thursdays <number> pm vespers amp meditation prayerful plainsong multisensory candles incense psalms music silence faithful sing listen',
#  'pray boy huff',
#  'gameday vs buford today at <number> <number> at home never been so excited',
#  'snap hi ale shia grinning face with big eyes',
#  'need stop second guess go first thought go',
#  '<number> meeting olympic house <number> golds <number> relentless never quit believe dream big team to going <number> gold',
#  '<user> offend weird',
#  'drop snap chat names bored swap pics',
#  'follow snap chat ghost carl abt st <number> snap chat',
#  'love girls busy teaching pout taking self ie mall desi cation immense women love perfection',
#  'follow girl tiff got <number> followers sparkling heart heart with arrow sparkling heart heart with arrow heart with arrow <user>',
#  '<user> peanut butter takes away sting',
#  'hate see frown would rather see smiling two hearts sparkles',
#  '<user> jared snap heart with arrow',
#  'kik want swap pics post account anonymously wish kik vs vp lou kik kik me nudes tits snap chat',
#  'ordered vacation bathing suits one less thing fret',
#  'cheap pout brod cast',
#  'ugh hh love clean house incense lit aromatherapy',
#  'follow snap chat ghost carl abt st <number> snap chat snap',
#  'vale vale sip sangria taste tantalizing tapas <user> fiery flamenco nights minutes from hom silverlake la flamenco',
#  'grateful hungry people life hungry learn change grow help etc sure anybody better relentless',
#  'love new song stop thinking sting',
#  '<user> just help maintain boost status world class centre education culture tolerance',
#  '<user> one favorite songs brother real talk',
#  'one month til someone bday think time flaunt got something pretty awesome',
#  '<user> <user> sting luckily he flew happy drunk lo lololol',
#  'ellie gave loads gifts notes em uni burst tears love her weary face',
#  '<user> <user> miss',
#  '<user> <user> wrath khan one best movies time',
#  'girly sense always lashes amp nails done tomboy sense black color amp refuse ruffle life',
#  'follow follow be relentless success',
#  '<user> turn frown upside',
#  '<user> it game day minus <number> <number>',
#  'rose incense best thing ever bought',
#  '<user> literally burst laughing',
#  'follow follow be success',
#  'wrinkles merely hide frown mark twain',
#  'love new song stop thinking']

# %%
# check
train_anger_intensities
# Out:
# [0.938,
#  0.8959999999999999,
#  0.8959999999999999,
#  0.8959999999999999,
#  0.8959999999999999,
#  0.875,
#  0.875,
#  0.875,
#  0.875,
#  0.875,
#  0.667,
#  0.8540000000000001,
#  0.8540000000000001,
#  0.938,
#  0.8540000000000001,
#  0.8540000000000001,
#  0.8540000000000001,
#  0.833,
#  0.833,
#  0.812,
#  0.812,
#  0.8909999999999999,
#  0.812,
#  0.812,
#  0.792,
#  0.792,
#  0.792,
#  0.792,
#  0.792,
#  0.792,
#  0.792,
#  0.792,
#  0.792,
#  0.792,
#  0.792,
#  0.792,
#  0.792,
#  0.792,
#  0.792,
#  0.7709999999999999,
#  0.9,
#  0.7709999999999999,
#  0.7709999999999999,
#  0.7709999999999999,
#  0.733,
#  0.7709999999999999,
#  0.7709999999999999,
#  0.7709999999999999,
#  0.7709999999999999,
#  0.7709999999999999,
#  0.75,
#  0.75,
#  0.84,
#  0.75,
#  0.75,
#  0.75,
#  0.75,
#  0.75,
#  0.75,
#  0.75,
#  0.75,
#  0.8440000000000001,
#  0.75,
#  0.75,
#  0.75,
#  0.885,
#  0.75,
#  0.75,
#  0.75,
#  0.875,
#  0.75,
#  0.75,
#  0.75,
#  0.75,
#  0.5529999999999999,
#  0.7290000000000001,
#  0.7290000000000001,
#  0.7290000000000001,
#  0.7290000000000001,
#  0.7290000000000001,
#  0.8640000000000001,
#  0.7290000000000001,
#  0.863,
#  0.7290000000000001,
#  0.7290000000000001,
#  0.873,
#  0.5379999999999999,
#  0.7290000000000001,
#  0.7290000000000001,
#  0.7290000000000001,
#  0.7290000000000001,
#  0.7290000000000001,
#  0.7290000000000001,
#  0.7290000000000001,
#  0.775,
#  0.867,
#  0.831,
#  0.708,
#  0.708,
#  0.708,
#  0.759,
#  0.862,
#  0.708,
#  0.708,
#  0.708,
#  0.708,
#  0.708,
#  0.708,
#  0.8170000000000001,
#  0.708,
#  0.708,
#  0.708,
#  0.708,
#  0.75,
#  0.688,
#  0.688,
#  0.688,
#  0.688,
#  0.69,
#  0.688,
#  0.688,
#  0.764,
#  0.688,
#  0.688,
#  0.688,
#  0.688,
#  0.688,
#  0.688,
#  0.688,
#  0.7659999999999999,
#  0.688,
#  0.688,
#  0.667,
#  0.667,
#  0.667,
#  0.667,
#  0.667,
#  0.578,
#  0.667,
#  0.667,
#  0.667,
#  0.667,
#  0.667,
#  0.667,
#  0.667,
#  0.833,
#  0.667,
#  0.667,
#  0.667,
#  0.667,
#  0.648,
#  0.667,
#  0.6459999999999999,
#  0.812,
#  0.6459999999999999,
#  0.6459999999999999,
#  0.6459999999999999,
#  0.6459999999999999,
#  0.6459999999999999,
#  0.6459999999999999,
#  0.6459999999999999,
#  0.6459999999999999,
#  0.6459999999999999,
#  0.6459999999999999,
#  0.6459999999999999,
#  0.6459999999999999,
#  0.6459999999999999,
#  0.6459999999999999,
#  0.6459999999999999,
#  0.6459999999999999,
#  0.6459999999999999,
#  0.6459999999999999,
#  0.6459999999999999,
#  0.556,
#  0.6459999999999999,
#  0.6459999999999999,
#  0.6459999999999999,
#  0.69,
#  0.6459999999999999,
#  0.6459999999999999,
#  0.6459999999999999,
#  0.6459999999999999,
#  0.6459999999999999,
#  0.6459999999999999,
#  0.47200000000000003,
#  0.625,
#  0.625,
#  0.531,
#  0.625,
#  0.625,
#  0.625,
#  0.625,
#  0.625,
#  0.625,
#  0.625,
#  0.625,
#  0.625,
#  0.625,
#  0.625,
#  0.625,
#  0.5429999999999999,
#  0.625,
#  0.5710000000000001,
#  0.625,
#  0.625,
#  0.625,
#  0.625,
#  0.625,
#  0.625,
#  0.625,
#  0.625,
#  0.625,
#  0.604,
#  0.604,
#  0.604,
#  0.604,
#  0.479,
#  0.46799999999999997,
#  0.604,
#  0.604,
#  0.604,
#  0.604,
#  0.604,
#  0.604,
#  0.604,
#  0.604,
#  0.604,
#  0.596,
#  0.604,
#  0.604,
#  0.527,
#  0.604,
#  0.604,
#  0.447,
#  0.583,
#  0.583,
#  0.583,
#  0.583,
#  0.583,
#  0.583,
#  0.629,
#  0.583,
#  0.583,
#  0.583,
#  0.583,
#  0.583,
#  0.583,
#  0.583,
#  0.583,
#  0.583,
#  0.583,
#  0.583,
#  0.583,
#  0.583,
#  0.5,
#  0.583,
#  0.583,
#  0.583,
#  0.583,
#  0.583,
#  0.583,
#  0.583,
#  0.583,
#  0.583,
#  0.562,
#  0.562,
#  0.562,
#  0.562,
#  0.562,
#  0.598,
#  0.562,
#  0.562,
#  0.562,
#  0.562,
#  0.562,
#  0.562,
#  0.562,
#  0.562,
#  0.519,
#  0.562,
#  0.562,
#  0.562,
#  0.562,
#  0.562,
#  0.562,
#  0.562,
#  0.562,
#  0.562,
#  0.562,
#  0.562,
#  0.562,
#  0.562,
#  0.562,
#  0.562,
#  0.562,
#  0.562,
#  0.562,
#  0.556,
#  0.562,
#  0.491,
#  0.562,
#  0.562,
#  0.542,
#  0.542,
#  0.593,
#  0.542,
#  0.42100000000000004,
#  0.542,
#  0.542,
#  0.517,
#  0.542,
#  0.542,
#  0.542,
#  0.542,
#  0.542,
#  0.542,
#  0.542,
#  0.525,
#  0.542,
#  0.542,
#  0.542,
#  0.542,
#  0.542,
#  0.542,
#  0.542,
#  0.542,
#  0.542,
#  0.542,
#  0.542,
#  0.542,
#  0.542,
#  0.542,
#  0.491,
#  0.542,
#  0.542,
#  0.519,
#  0.542,
#  0.542,
#  0.542,
#  0.542,
#  0.542,
#  0.542,
#  0.542,
#  0.521,
#  0.521,
#  0.521,
#  0.521,
#  0.521,
#  0.521,
#  0.521,
#  0.521,
#  0.521,
#  0.521,
#  0.45799999999999996,
#  0.521,
#  0.5,
#  0.521,
#  0.521,
#  0.517,
#  0.415,
#  0.521,
#  0.5660000000000001,
#  0.521,
#  0.521,
#  0.521,
#  0.521,
#  0.521,
#  0.521,
#  0.521,
#  0.574,
#  0.521,
#  0.521,
#  0.521,
#  0.373,
#  0.521,
#  0.521,
#  0.521,
#  0.521,
#  0.521,
#  0.521,
#  0.521,
#  0.521,
#  0.521,
#  0.521,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.52,
#  0.5,
#  0.5,
#  0.4,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.484,
#  0.5,
#  0.494,
#  0.5,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.33299999999999996,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.479,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.579,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.45799999999999996,
#  0.43799999999999994,
#  0.441,
#  0.414,
#  0.43799999999999994,
#  0.48100000000000004,
#  0.43799999999999994,
#  0.466,
#  0.43799999999999994,
#  0.43799999999999994,
#  0.43799999999999994,
#  0.43799999999999994,
#  0.43799999999999994,
#  0.43799999999999994,
#  0.462,
#  0.43799999999999994,
#  0.43799999999999994,
#  0.43799999999999994,
#  0.43799999999999994,
#  0.43799999999999994,
#  0.43799999999999994,
#  0.43799999999999994,
#  0.43799999999999994,
#  0.43799999999999994,
#  0.43799999999999994,
#  0.43799999999999994,
#  0.43799999999999994,
#  0.43799999999999994,
#  0.47200000000000003,
#  0.43799999999999994,
#  0.43799999999999994,
#  0.43799999999999994,
#  0.43799999999999994,
#  0.43799999999999994,
#  0.43799999999999994,
#  0.491,
#  0.49200000000000005,
#  0.43799999999999994,
#  0.43799999999999994,
#  0.43799999999999994,
#  0.43799999999999994,
#  0.43799999999999994,
#  0.43799999999999994,
#  0.43799999999999994,
#  0.43799999999999994,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.442,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.46799999999999997,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.242,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.29,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.434,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.254,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.41700000000000004,
#  0.396,
#  0.396,
#  0.396,
#  0.396,
#  0.396,
#  0.396,
#  0.396,
#  0.396,
#  0.42700000000000005,
#  0.396,
#  0.396,
#  0.396,
#  0.396,
#  0.396,
#  0.396,
#  0.396,
#  0.396,
#  0.396,
#  0.396,
#  0.396,
#  0.396,
#  0.396,
#  0.396,
#  0.396,
#  0.396,
#  0.396,
#  0.396,
#  0.396,
#  0.396,
#  0.396,
#  0.42200000000000004,
#  0.433,
#  0.396,
#  0.396,
#  0.396,
#  0.396,
#  0.231,
#  0.375,
#  0.435,
#  0.255,
#  0.375,
#  0.375,
#  0.375,
#  0.375,
#  0.375,
#  0.375,
#  0.375,
#  0.375,
#  0.375,
#  0.375,
#  0.375,
#  0.375,
#  0.35600000000000004,
#  0.375,
#  0.375,
#  0.375,
#  0.375,
#  0.425,
#  0.375,
#  0.37,
#  0.314,
#  0.375,
#  0.375,
#  0.375,
#  0.375,
#  0.375,
#  0.375,
#  0.375,
#  0.375,
#  0.375,
#  0.375,
#  0.375,
#  0.444,
#  0.375,
#  0.375,
#  0.375,
#  0.375,
#  0.375,
#  0.425,
#  0.354,
#  0.354,
#  0.354,
#  0.354,
#  0.2,
#  0.354,
#  0.35600000000000004,
#  0.322,
#  0.354,
#  0.354,
#  0.354,
#  0.354,
#  0.354,
#  0.32799999999999996,
#  0.354,
#  0.354,
#  0.354,
#  0.354,
#  0.354,
#  0.354,
#  0.354,
#  0.354,
#  0.354,
#  0.354,
#  0.354,
#  0.354,
#  0.354,
#  0.354,
#  0.354,
#  0.354,
#  0.354,
#  0.177,
#  0.354,
#  0.354,
#  0.33299999999999996,
#  0.33299999999999996,
#  0.33299999999999996,
#  0.33299999999999996,
#  0.33299999999999996,
#  0.33299999999999996,
#  0.33299999999999996,
#  0.33299999999999996,
#  0.33299999999999996,
#  0.33299999999999996,
#  0.33299999999999996,
#  0.33299999999999996,
#  0.33299999999999996,
#  0.33299999999999996,
#  0.33299999999999996,
#  0.33299999999999996,
#  0.29600000000000004,
#  0.33299999999999996,
#  0.33299999999999996,
#  0.33299999999999996,
#  0.33299999999999996,
#  0.33299999999999996,
#  0.341,
#  0.33299999999999996,
#  0.312,
#  0.312,
#  0.312,
#  0.312,
#  0.312,
#  0.172,
#  0.312,
#  0.389,
#  0.312,
#  0.312,
#  0.312,
#  0.33,
#  0.312,
#  0.312,
#  0.312,
#  0.312,
#  0.312,
#  0.312,
#  0.312,
#  0.312,
#  0.312,
#  0.312,
#  0.312,
#  0.292,
#  0.185,
#  0.292,
#  0.222,
#  0.182,
#  0.292,
#  0.292,
#  0.292,
#  0.35700000000000004,
#  0.292,
#  0.292,
#  0.292,
#  0.304,
#  0.292,
#  0.292,
#  0.271,
#  0.271,
#  0.271,
#  0.271,
#  0.271,
#  0.271,
#  0.271,
#  0.271,
#  0.271,
#  0.271,
#  0.271,
#  0.271,
#  0.271,
#  0.271,
#  0.271,
#  0.271,
#  0.271,
#  0.271,
#  0.271,
#  0.295,
#  0.18899999999999997,
#  0.25,
#  0.25,
#  0.25,
#  0.25,
#  0.25,
#  0.25,
#  0.25,
#  0.324,
#  0.25,
#  0.25,
#  0.22899999999999998,
#  0.22899999999999998,
#  0.20199999999999999,
#  0.147,
#  0.22899999999999998,
#  0.22899999999999998,
#  0.20800000000000002,
#  0.127,
#  0.20800000000000002,
#  0.20800000000000002,
#  0.20800000000000002,
#  0.20800000000000002,
#  0.20800000000000002,
#  0.20800000000000002,
#  0.20800000000000002,
#  0.188,
#  0.188,
#  0.188,
#  0.188,
#  0.188,
#  0.188,
#  0.188,
#  0.188,
#  0.188,
#  0.188,
#  0.23199999999999998,
#  0.26,
#  0.16699999999999998,
#  0.16699999999999998,
#  0.16699999999999998,
#  0.16699999999999998,
#  0.16699999999999998,
#  0.157,
#  0.14300000000000002,
#  0.146,
#  0.146,
#  0.146,
#  0.146,
#  0.146,
#  0.125,
#  0.125,
#  0.125,
#  0.125,
#  0.067,
#  0.125,
#  0.125,
#  0.083]

# %%
dev_anger_tweets = list(dev_anger['Tweet'])
dev_anger_intensities = list(dev_anger['Rating'])

dev_fear_tweets = list(dev_fear['Tweet'])
dev_fear_intensities = list(dev_fear['Rating'])

dev_sadness_tweets = list(dev_sadness['Tweet'])
dev_sadness_intensities = list(dev_sadness['Rating'])

dev_joy_tweets = list(dev_joy['Tweet'])
dev_joy_intensities = list(dev_joy['Rating'])

# %%
test_anger_tweets = list(test_anger['Tweet'])
test_anger_intensities = list(test_anger['Rating'])

test_fear_tweets = list(test_fear['Tweet'])
test_fear_intensities = list(test_fear['Rating'])

test_sadness_tweets = list(test_sadness['Tweet'])
test_sadness_intensities = list(test_sadness['Rating'])

test_joy_tweets = list(test_joy['Tweet'])
test_joy_intensities = list(test_joy['Rating'])

# %%
# show Max Text Length of All Datasets for comparsion

all_tweets_max_len = pd.DataFrame(np.array([max(show_text_len(train_anger)), max(show_text_len(train_fear)), max(show_text_len(train_joy)),\
                              max(show_text_len(train_sadness)), max(show_text_len(dev_anger)), max(show_text_len(dev_fear)),\
                                  max(show_text_len(dev_joy)), max(show_text_len(dev_sadness)), max(show_text_len(test_anger)),\
                                  max(show_text_len(test_fear)), max(show_text_len(test_joy)), max(show_text_len(test_sadness))]))

all_tweets_max_len.index = ['train_anger', 'train_fear', 'train_joy', 'train_sadness', 'dev_anger', 'dev_fear', 'dev_joy', 'dev_sadness',\
                            'test_anger', 'test_fear', 'test_joy', 'test_sadness']
all_tweets_max_len.columns = ['max text length']

all_tweets_max_len
# Out:
#                max text length
# train_anger                 77
# train_fear                  28
# train_joy                   33
# train_sadness               79
# dev_anger                   21
# dev_fear                    24
# dev_joy                     23
# dev_sadness                 30
# test_anger                  43
# test_fear                   38
# test_joy                    42
# test_sadness                27

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
all_tweets_max_len.plot(kind='bar')
plt.title('Max Text Length of All Datasets')
plt.show()

# %%
'''
we set the length to which each tweet vector will be zero padded to.
this is based on the maximum length we got on the training set - we do not want to remove
any words as the maximun length of the training set is not very big.
'''

max_len = max(max(show_text_len(train_anger)), max(show_text_len(train_fear)), max(show_text_len(train_joy)),\
             max(show_text_len(train_sadness)))
max_len
# Out:
# 79

# %% [markdown]
# # 2) Encode Text Data (Prepare Input for the Deep Learning Model)

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing .sequence import pad_sequences
# Out:
# Using TensorFlow backend.

# %%
# fit a tokenizer
def create_tokenizer(text):
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(text)
    return tokenizer

# integer encode and pad documents                                                                                                                                 
def encode_text(tokenizer, max_length, text):
    # integer encode
    encoded = tokenizer.texts_to_sequences(text)
    # pad sequences
    padded = pad_sequences(encoded, maxlen = max_length, padding = 'post', truncating='post')
    return padded

# %%
# create the tokenizer
# Tokenizer based on all TEXTS (the training datasets + the development datasets!!!) (not include the testing datasets！！！)
all_text = train_anger_tweets + train_fear_tweets + train_sadness_tweets + train_joy_tweets + dev_anger_tweets + dev_fear_tweets +\
dev_sadness_tweets + dev_joy_tweets

tokenizer = create_tokenizer(all_text)

# define vocabulary size
vocab_size = len(tokenizer.word_index) + 1
print('Vocabulary size: %d' % vocab_size)

print('Maximum length: %d' % max_len)

# encode data
train_anger_vecs = encode_text(tokenizer, max_len, train_anger_tweets)
train_fear_vecs = encode_text(tokenizer, max_len, train_fear_tweets)
train_sadness_vecs = encode_text(tokenizer, max_len, train_sadness_tweets)
train_joy_vecs = encode_text(tokenizer, max_len, train_joy_tweets)

dev_anger_vecs = encode_text(tokenizer, max_len, dev_anger_tweets)
dev_fear_vecs = encode_text(tokenizer, max_len, dev_fear_tweets)
dev_sadness_vecs = encode_text(tokenizer, max_len, dev_sadness_tweets)
dev_joy_vecs = encode_text(tokenizer, max_len, dev_joy_tweets)

test_anger_vecs = encode_text(tokenizer, max_len, test_anger_tweets)
test_fear_vecs = encode_text(tokenizer, max_len, test_fear_tweets)
test_sadness_vecs = encode_text(tokenizer, max_len, test_sadness_tweets)
test_joy_vecs = encode_text(tokenizer, max_len, test_joy_tweets)
# Out:
# Vocabulary size: 8263
# Maximum length: 79

# %%
# do a sanity check
print(train_anger_vecs)
# Out:
# [[ 145  146  407 ...    0    0    0]
#  [  86  546 1132 ...    0    0    0]
#  [   1  321 2722 ...    0    0    0]
#  ...
#  [ 230  230   48 ...    0    0    0]
#  [5226 5227 1788 ...    0    0    0]
#  [  17   63  623 ...    0    0    0]]

# %%
# save the tokenizer for later use (in case)
from pickle import dump
# save the tokenizer
dump(tokenizer, open('tokenizer.pkl', 'wb'))

# %% [markdown]
# # 3) Prepare Embedding_vectors as Weights of the Deep Learning Model's Embedding Layer

# %%
# create a weight matrix for the Embedding layer from a loaded embedding

def get_weight_matrix(model, vocab, embedding_dim, vocab_size):
    weight_matrix = np.zeros((vocab_size,embedding_dim))
    for word, i in vocab.items():
        if i < vocab_size:
            embedding_vector = model.get(word)
            if embedding_vector is not None:
                weight_matrix[i] = embedding_vector
    return weight_matrix

# %%
# get vectors in the right order. vocab_size = len(tokenizer.word_index) + 1 was defined above.
embedding_vectors = get_weight_matrix(wv_model_g, tokenizer.word_index, 100, vocab_size)

# do a sanity check
pd.DataFrame(embedding_vectors)
# Out:
#            0         1        2         3        4         5         6   \
# 0     0.00000  0.000000  0.00000  0.000000  0.00000  0.000000  0.000000
# 1     0.53558 -0.002531 -0.60355  0.553890  0.94984 -0.348110  0.438700
# 2     0.18440  0.257060 -0.06333  0.134800  0.42694 -0.025103  0.586500
# 3     0.51758 -0.433470 -0.31972  0.297910  0.75536 -0.015408  0.490540
# 4    -0.21063 -0.010992 -0.17552  0.472330 -0.21738  0.416980  0.159160
# ...       ...       ...      ...       ...      ...       ...       ...
# 8258 -0.92101  0.024585  0.43403  0.580120  0.31242 -1.087600 -1.771200
# 8259 -0.21308  0.519990 -0.31222  0.751110  0.33503  0.480590  0.099205
# 8260 -0.32996 -0.129930  0.12608 -0.082324 -0.45618 -0.958740  0.368680
# 8261  0.20557  0.266330  0.46410 -1.345800 -0.54587 -0.755340 -0.972800
# 8262 -0.50414 -0.049774 -1.05030  0.469250  0.26934 -0.453610  0.287960
#
#             7         8         9   ...        90        91       92  \
# 0     0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.00000
# 1    -0.038687  0.097746 -0.184050  ... -0.419590  0.331240  0.39939
# 2     0.487310  0.190220  0.505140  ...  0.245610  0.178940 -0.47800
# 3     0.050071  0.132380  0.079876  ... -0.470460 -0.683310  0.13036
# 4    -0.048584 -0.113570  0.252440  ...  0.075953  0.075035 -0.46835
# ...        ...       ...       ...  ...       ...       ...      ...
# 8258 -0.549770  0.660770  0.679820  ... -0.333740  0.265470  0.37675
# 8259  0.896960 -0.235460  0.330510  ... -0.620620 -0.011245  0.42604
# 8260 -0.218680 -0.457400 -0.689200  ...  0.166080  0.514600  0.50232
# 8261  0.694030  0.597950  0.414440  ...  0.245540  0.165230  0.27672
# 8262 -0.097054 -0.455590  1.161000  ... -0.096803 -0.083955 -0.17148
#
#             93        94        95        96        97        98       99
# 0     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 1    -0.574520  0.810910 -0.913400  0.087823 -0.109170  0.267240  0.38322
# 2    -0.160240  0.237690  0.009213 -0.322970  0.066975  0.340560 -0.10015
# 3    -0.485130  0.372700 -0.207770  0.037162 -0.564950 -0.093079  0.55105
# 4     0.003926 -0.074690  0.273780 -0.235610 -0.375470  0.580290  0.16067
# ...        ...       ...       ...       ...       ...       ...      ...
# 8258 -0.481960  0.645760 -0.898030  0.645770 -0.453560 -0.078798  0.47290
# 8259 -0.347390 -0.226320 -0.258760  0.627520 -0.169200 -0.763330  0.66409
# 8260  0.848620  0.015386 -0.007224  0.623510  0.406820 -0.183590  0.15557
# 8261  0.200130  0.928670 -0.416070 -0.076809  0.733850  0.114400  0.22435
# 8262  0.088864  0.465640  0.047227 -0.711890  0.530620  1.121800 -0.14498
#
# [8263 rows x 100 columns]

# %% [markdown]
#  # 4)  Save Embedding_vectors & Train Vectors & Dev. Vectors & Test Vectors

# %%
np.save('files/embedding_vectors/glove_embedding_vectors.npy', embedding_vectors)
print('Embedding Vectors Saved')
# Out:
# Embedding Vectors Saved

# %%
np.save('files/train_vectors/train_anger_vecs.npy',train_anger_vecs)
np.save('files/train_vectors/train_fear_vecs.npy',train_fear_vecs)
np.save('files/train_vectors/train_sadness_vecs.npy',train_sadness_vecs)
np.save('files/train_vectors/train_joy_vecs.npy',train_joy_vecs)

print('Train Vectors Saved')
# Out:
# Train Vectors Saved

# %%
np.save('files/dev_vectors/dev_anger_vecs.npy',dev_anger_vecs)
np.save('files/dev_vectors/dev_fear_vecs.npy',dev_fear_vecs)
np.save('files/dev_vectors/dev_sadness_vecs.npy',dev_sadness_vecs)
np.save('files/dev_vectors/dev_joy_vecs.npy',dev_joy_vecs)

print('Dev Vectors Saved')
# Out:
# Dev Vectors Saved

# %%
np.save('files/test_vectors/test_anger_vecs.npy',test_anger_vecs)
np.save('files/test_vectors/test_fear_vecs.npy',test_fear_vecs)
np.save('files/test_vectors/test_sadness_vecs.npy',test_sadness_vecs)
np.save('files/test_vectors/test_joy_vecs.npy',test_joy_vecs)

print('Test Vectors Saved')
# Out:
# Test Vectors Saved
